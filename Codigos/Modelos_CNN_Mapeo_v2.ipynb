# %%
import pandas as pd

# %%
df = pd.read_excel('../Datos/DB_Comentarios_Clean.xlsx')

# %%
df.head()
# Out:
#           fecha  calificacion  \
# 0  01 ene. 2024             1
# 1  01 may. 2023             1
# 2  02 oct. 2024             1
# 3  02 sep. 2019             1
# 4  03 ene. 2025             1
#
#                                           comentario  \
# 0  Producto con terminados horribles, manchado, p...
# 1  El producto es un poco ordinario y tuve que ma...
# 2                                  Talla incorrecta.
# 3               Definitivamente no cuadra en el pie.
# 4  No son nada cómodos, la plantilla se corre y l...
#
#                            comentarios_limpios_spacy
# 0  terminado horrible manchado pintura corrido di...
# 1  ordinario tener mandar él reparar rapido mes c...
# 2                                  tallar incorrecto
# 3                        definitivamente cuadrar pie
# 4              comodo plantilla correr suela delgado

# %%
# eliminar valores nulos
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# fecha                        0
# calificacion                 0
# comentario                   0
# comentarios_limpios_spacy    0
# dtype: int64

# %% [markdown]
# #

# %%
# mapeo de estrellas a sentimiento, (1y2 = negativo, 3 = neutro, 4y5 = positivo)

# Definir el mapeo estrellas → sentimiento (texto)
rating_to_label = {
    1: "negativo",
    2: "negativo",
    3: "negativo",
    4: "positivo",
    5: "positivo",
}

# Aplicar el mapeo
df["sentimiento"] = df["calificacion"].map(rating_to_label)

# 4. Codificar la etiqueta a valor numérico
#label_to_int = {"negativo": 0, "neutro": 1, "positivo": 2}
label_to_int = {"negativo": 0, "positivo": 1}
df["sentimiento_id"] = df["sentimiento"].map(label_to_int)

# 5. Revisar la distribución resultante
print(df["sentimiento"].value_counts())
# Out:
# sentimiento
# positivo    4073
# negativo     400
# Name: count, dtype: int64

# %%
df.head()
# Out:
#           fecha  calificacion  \
# 0  01 ene. 2024             1
# 1  01 may. 2023             1
# 2  02 oct. 2024             1
# 3  02 sep. 2019             1
# 4  03 ene. 2025             1
#
#                                           comentario  \
# 0  Producto con terminados horribles, manchado, p...
# 1  El producto es un poco ordinario y tuve que ma...
# 2                                  Talla incorrecta.
# 3               Definitivamente no cuadra en el pie.
# 4  No son nada cómodos, la plantilla se corre y l...
#
#                            comentarios_limpios_spacy sentimiento  \
# 0  terminado horrible manchado pintura corrido di...    negativo
# 1  ordinario tener mandar él reparar rapido mes c...    negativo
# 2                                  tallar incorrecto    negativo
# 3                        definitivamente cuadrar pie    negativo
# 4              comodo plantilla correr suela delgado    negativo
#
#    sentimiento_id
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
MAX_NUM_WORDS = 10000        # Tamaño del vocabulario (palabras más frecuentes)
MAX_SEQUENCE_LENGTH = 50     # Longitud fija de cada comentario (en tokens)
EMBEDDING_DIM = 100          # Tamaño del embedding vector (100 es estándar)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Inicializar el tokenizador
tokenizer = Tokenizer(num_words=MAX_NUM_WORDS, oov_token="<OOV>")
tokenizer.fit_on_texts(df["comentarios_limpios_spacy"])

# Convertir texto a secuencia de enteros
sequences = tokenizer.texts_to_sequences(df["comentarios_limpios_spacy"])

# Padding: hacer que todas las secuencias tengan la misma longitud
X = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, padding="post", truncating="post")

# %%
tokenizer.word_index
# Out:
# {'<OOV>': 1,
#  'excelente': 2,
#  'comoda': 3,
#  'talla': 4,
#  'comodo': 5,
#  'bonito': 6,
#  'super': 7,
#  'quedar': 8,
#  'material': 9,
#  'esperar': 10,
#  'lindo': 11,
#  'suave': 12,
#  'encantar': 13,
#  'perfecto': 14,
#  'precio': 15,
#  'recomendado': 16,
#  'pie': 17,
#  'suela': 18,
#  'recomeir': 19,
#  'foto': 20,
#  'gustar': 21,
#  'ver': 22,
#  'pedir': 23,
#  'justo': 24,
#  'pedi': 25,
#  'gracias': 26,
#  'pequena': 27,
#  'comprar': 28,
#  'él': 29,
#  'quedo': 30,
#  'pantufla': 31,
#  'diseno': 32,
#  'zapato': 33,
#  'hermosa': 34,
#  'regalo': 35,
#  'cumplir': 36,
#  'color': 37,
#  'gusto': 38,
#  'compra': 39,
#  'gracia': 40,
#  'bonita': 41,
#  'parecer': 42,
#  'pequeno': 43,
#  'medida': 44,
#  'satisfecho': 45,
#  'hermoso': 46,
#  'sentir': 47,
#  'casa': 48,
#  'caminar': 49,
#  'genial': 50,
#  'rapido': 51,
#  'esperado': 52,
#  'babucha': 53,
#  'imagen': 54,
#  'playa': 55,
#  'expectativa': 56,
#  'numero': 57,
#  'compre': 58,
#  'frio': 59,
#  'comodas': 60,
#  'exelente': 61,
#  'hijo': 62,
#  'tallar': 63,
#  'venir': 64,
#  'terminado': 65,
#  'pequén': 66,
#  'unico': 67,
#  'tener': 68,
#  'acorde': 69,
#  'acabado': 70,
#  'relacion': 71,
#  'liviana': 72,
#  'malo': 73,
#  'comodidad': 74,
#  'usar': 75,
#  'resistente': 76,
#  'feliz': 77,
#  'delgado': 78,
#  'q': 79,
#  '100': 80,
#  'cumplio': 81,
#  'resto': 82,
#  'necesitar': 83,
#  'duro': 84,
#  'facil': 85,
#  'descripcion': 86,
#  'tallaje': 87,
#  'persona': 88,
#  'arena': 89,
#  'ajustar': 90,
#  'salir': 91,
#  'tiempo': 92,
#  'realmente': 93,
#  'par': 94,
#  'nino': 95,
#  'normalmente': 96,
#  'chancla': 97,
#  'comprir': 98,
#  'normal': 99,
#  'confortabl': 100,
#  'piso': 101,
#  'llegar': 102,
#  'tocar': 103,
#  'preciso': 104,
#  'agua': 105,
#  'acolchada': 106,
#  'tamano': 107,
#  'caliente': 108,
#  'liviano': 109,
#  'hija': 110,
#  'espectacular': 111,
#  'espectativa': 112,
#  'calientita': 113,
#  'totalmente': 114,
#  'mes': 115,
#  'plantilla': 116,
#  'tabla': 117,
#  'calientica': 118,
#  'general': 119,
#  'cambiar': 120,
#  'rio': 121,
#  'corresponder': 122,
#  'sandalia': 123,
#  'exacto': 124,
#  'recomendable': 125,
#  'agradable': 126,
#  'practico': 127,
#  'problema': 128,
#  'antideslizante': 129,
#  'grueso': 130,
#  'funcion': 131,
#  'antideslizant': 132,
#  'contento': 133,
#  'elaborado': 134,
#  'calient': 135,
#  'semana': 136,
#  'calentar': 137,
#  'mostrar': 138,
#  'calzado': 139,
#  'adecuado': 140,
#  'andar': 141,
#  'correcto': 142,
#  'exactamente': 143,
#  'hecho': 144,
#  'util': 145,
#  'perfecta': 146,
#  'esposa': 147,
#  'servir': 148,
#  'ofrecer': 149,
#  'buscar': 150,
#  'calentita': 151,
#  'durar': 152,
#  'parecio': 153,
#  'quitar': 154,
#  'ideal': 155,
#  'danar': 156,
#  'funcionar': 157,
#  'guia': 158,
#  'forma': 159,
#  'costura': 160,
#  'publicacion': 161,
#  'detalle': 162,
#  'ajustado': 163,
#  'mantener': 164,
#  'madre': 165,
#  'romper': 166,
#  'deberiar': 167,
#  'suelar': 168,
#  'regalar': 169,
#  'valer': 170,
#  'encantado': 171,
#  'costo': 172,
#  'alto': 173,
#  'esposo': 174,
#  'regular': 175,
#  'tela': 176,
#  'aparecer': 177,
#  'poquito': 178,
#  'media': 179,
#  'horma': 180,
#  'estar': 181,
#  'duradero': 182,
#  'mama': 183,
#  'chever': 184,
#  'ir': 185,
#  'seguro': 186,
#  'calzar': 187,
#  'divina': 188,
#  'pena': 189,
#  'mar': 190,
#  'ancho': 191,
#  'calzo': 192,
#  'agarre': 193,
#  'bello': 194,
#  'despegar': 195,
#  'original': 196,
#  'utilizar': 197,
#  'costoso': 198,
#  'llevar': 199,
#  'espuma': 200,
#  'poder': 201,
#  'pensar': 202,
#  'faltar': 203,
#  'mejorar': 204,
#  'importante': 205,
#  'abrigada': 206,
#  'principio': 207,
#  'precioso': 208,
#  'igual': 209,
#  'hacer': 210,
#  'cambio': 211,
#  'comprado': 212,
#  'pense': 213,
#  'querer': 214,
#  'economica': 215,
#  'ser': 216,
#  'descansar': 217,
#  'descanso': 218,
#  'pagina': 219,
#  'clima': 220,
#  'bonitas': 221,
#  'diente': 222,
#  'interior': 223,
#  'beneficio': 224,
#  'marca': 225,
#  'poner': 226,
#  'deformar': 227,
#  'ningun': 228,
#  'cm': 229,
#  'caso': 230,
#  'modelo': 231,
#  'secar': 232,
#  'ano': 233,
#  'confeccion': 234,
#  'dar': 235,
#  'salio': 236,
#  'funcional': 237,
#  'seriar': 238,
#  'recomendar': 239,
#  'suavecita': 240,
#  'opcion': 241,
#  'confortable': 242,
#  'incomoda': 243,
#  'calza': 244,
#  'muchisimo': 245,
#  'barato': 246,
#  'habitual': 247,
#  'talon': 248,
#  'comentario': 249,
#  'recibi': 250,
#  'plastico': 251,
#  'acolchado': 252,
#  'dejar': 253,
#  'sensacion': 254,
#  'mejor': 255,
#  'linda': 256,
#  'haber': 257,
#  'deslizar': 258,
#  'reducido': 259,
#  'pasar': 260,
#  'recomendacion': 261,
#  'volverio': 262,
#  'describir': 263,
#  'confeccionado': 264,
#  'ok': 265,
#  'practica': 266,
#  'limpiar': 267,
#  'novia': 268,
#  'contentar': 269,
#  'publicidad': 270,
#  'olor': 271,
#  'especificación': 272,
#  'calle': 273,
#  'postura': 274,
#  'hora': 275,
#  'presentacion': 276,
#  'comprador': 277,
#  'zuela': 278,
#  'imaginar': 279,
#  'piedra': 280,
#  'recibir': 281,
#  'cuidado': 282,
#  'calida': 283,
#  'empeine': 284,
#  'papa': 285,
#  'fuerte': 286,
#  'momento': 287,
#  'queria': 288,
#  'seguir': 289,
#  'dema': 290,
#  'abrigadora': 291,
#  'lleno': 292,
#  'probar': 293,
#  'bordado': 294,
#  'padre': 295,
#  'colombiano': 296,
#  'interno': 297,
#  'inconveniente': 298,
#  'facilidad': 299,
#  'ojo': 300,
#  'telar': 301,
#  'estrecho': 302,
#  'traer': 303,
#  'chico': 304,
#  'desgastar': 305,
#  'orma': 306,
#  'objetivo': 307,
#  'entrar': 308,
#  'deberio': 309,
#  'pesado': 310,
#  'confort': 311,
#  'tipo': 312,
#  'deber': 313,
#  'planta': 314,
#  'soler': 315,
#  'relleno': 316,
#  'durabilidad': 317,
#  'viaje': 318,
#  'resultar': 319,
#  'meter': 320,
#  'sugerir': 321,
#  'calientito': 322,
#  'elegante': 323,
#  'necesidad': 324,
#  'calientico': 325,
#  'sorprender': 326,
#  'fotografia': 327,
#  'estilo': 328,
#  'bn': 329,
#  'nina': 330,
#  'superar': 331,
#  'bebe': 332,
#  'extremadamente': 333,
#  'porq': 334,
#  'realidad': 335,
#  'responder': 336,
#  'pisar': 337,
#  'devolver': 338,
#  'ejemplo': 339,
#  'caer': 340,
#  'punto': 341,
#  'descocio': 342,
#  'terminar': 343,
#  'cubrir': 344,
#  'cansar': 345,
#  'flexible': 346,
#  'valor': 347,
#  'empezar': 348,
#  'referencia': 349,
#  'fino': 350,
#  'piscina': 351,
#  'yo': 352,
#  'base': 353,
#  'ofertado': 354,
#  'comodos': 355,
#  'molestar': 356,
#  'caracteristica': 357,
#  'fiel': 358,
#  'opinion': 359,
#  'permitir': 360,
#  'compren': 361,
#  'perfectamente': 362,
#  'medir': 363,
#  'evitar': 364,
#  'rico': 365,
#  'lavar': 366,
#  'queriar': 367,
#  'conforme': 368,
#  'amar': 369,
#  'articulo': 370,
#  'pintura': 371,
#  'pesimo': 372,
#  'rigido': 373,
#  'caro': 374,
#  'coincidir': 375,
#  'aguantar': 376,
#  'sacar': 377,
#  'solicitado': 378,
#  'superficie': 379,
#  'real': 380,
#  'suponer': 381,
#  'encontrar': 382,
#  'superior': 383,
#  'usual': 384,
#  'dedo': 385,
#  'calor': 386,
#  'chica': 387,
#  'puntual': 388,
#  '38': 389,
#  'pidio': 390,
#  'tenis': 391,
#  'veiar': 392,
#  'x': 393,
#  'esperabar': 394,
#  'garra': 395,
#  '40': 396,
#  'usualmente': 397,
#  '41': 398,
#  'maravilla': 399,
#  'calidad': 400,
#  'cumplimiento': 401,
#  'secado': 402,
#  'anuncio': 403,
#  'estupendo': 404,
#  'notar': 405,
#  'rapidamente': 406,
#  'increible': 407,
#  'preciosa': 408,
#  'comprare': 409,
#  'escoger': 410,
#  'ame': 411,
#  'pareja': 412,
#  'compro': 413,
#  'producto': 414,
#  'horrible': 415,
#  'ordinario': 416,
#  'termino': 417,
#  'decir': 418,
#  'supremamente': 419,
#  'ortopedica': 420,
#  'oler': 421,
#  'abrir': 422,
#  'incomodo': 423,
#  'liso': 424,
#  'sentido': 425,
#  'anunciar': 426,
#  'blanco': 427,
#  'punta': 428,
#  'mano': 429,
#  'noche': 430,
#  'prometer': 431,
#  'claro': 432,
#  'delgar': 433,
#  'volveria': 434,
#  'experiencia': 435,
#  'agrandar': 436,
#  'lado': 437,
#  'usando': 438,
#  'adulto': 439,
#  'respuesta': 440,
#  'suficiente': 441,
#  'apretado': 442,
#  'cuero': 443,
#  'desear': 444,
#  'rompio': 445,
#  'suelo': 446,
#  'dificil': 447,
#  'cerrado': 448,
#  'lastimar': 449,
#  'economico': 450,
#  'revisar': 451,
#  'cosa': 452,
#  'ajuste': 453,
#  'tobillo': 454,
#  'sobrina': 455,
#  'indicar': 456,
#  'pantunfla': 457,
#  'apretar': 458,
#  'peso': 459,
#  'durir': 460,
#  '39': 461,
#  'abrigado': 462,
#  'divino': 463,
#  'puesto': 464,
#  'angosto': 465,
#  'plano': 466,
#  'ayudar': 467,
#  'estetico': 468,
#  'colombia': 469,
#  'gris': 470,
#  'execelente': 471,
#  'firme': 472,
#  'recibio': 473,
#  'corto': 474,
#  'serio': 475,
#  'pagar': 476,
#  'especial': 477,
#  'satisfaccion': 478,
#  'bogota': 479,
#  'l': 480,
#  'miedo': 481,
#  'condición': 482,
#  'disenada': 483,
#  'materia': 484,
#  'alguien': 485,
#  'pedirla': 486,
#  'full': 487,
#  'apropiado': 488,
#  'hermana': 489,
#  'fantastica': 490,
#  'excepcional': 491,
#  'cumplido': 492,
#  'comida': 493,
#  'sobrino': 494,
#  'correr': 495,
#  'descoseír': 496,
#  'subir': 497,
#  'menor': 498,
#  'enganós': 499,
#  'perder': 500,
#  'dinero': 501,
#  'novio': 502,
#  'devolvi': 503,
#  'pese': 504,
#  'terrible': 505,
#  'caber': 506,
#  'comprarla': 507,
#  'usado': 508,
#  'pen': 509,
#  'empaque': 510,
#  'garantia': 511,
#  'demas': 512,
#  'descoceír': 513,
#  'abajo': 514,
#  'dano': 515,
#  'ampolla': 516,
#  'negra': 517,
#  'mojado': 518,
#  'anchas': 519,
#  'generar': 520,
#  'trabajo': 521,
#  'caucho': 522,
#  'completamente': 523,
#  'cordón': 524,
#  'resulto': 525,
#  'fria': 526,
#  'medio': 527,
#  'izquierdo': 528,
#  'lavadora': 529,
#  'suavidad': 530,
#  'mover': 531,
#  'tender': 532,
#  'soltar': 533,
#  'mujer': 534,
#  'pequenar': 535,
#  'larga': 536,
#  'lastimosamente': 537,
#  'aparte': 538,
#  'avisar': 539,
#  'sudar': 540,
#  'calido': 541,
#  'diario': 542,
#  'resbalar': 543,
#  'inicio': 544,
#  'azul': 545,
#  'ingresar': 546,
#  'blando': 547,
#  'volverir': 548,
#  'verificar': 549,
#  'inferior': 550,
#  'proteccion': 551,
#  'recomendariar': 552,
#  'textura': 553,
#  'resistencia': 554,
#  'san': 555,
#  'andr': 556,
#  'ligero': 557,
#  'perfeccion': 558,
#  'tema': 559,
#  'blandita': 560,
#  'peluche': 561,
#  'cerdito': 562,
#  'esteticamente': 563,
#  'adicional': 564,
#  'camine': 565,
#  'nube': 566,
#  'ormar': 567,
#  'belleza': 568,
#  'solicitar': 569,
#  'fina': 570,
#  'cheverar': 571,
#  'gustariar': 572,
#  'terminacion': 573,
#  'calir': 574,
#  'bue': 575,
#  'sugerencia': 576,
#  'justa': 577,
#  'fabricado': 578,
#  'zapatilla': 579,
#  'escogi': 580,
#  'pulido': 581,
#  'tierno': 582,
#  'colocar': 583,
#  'trabajar': 584,
#  'd': 585,
#  'queja': 586,
#  'caminata': 587,
#  'prueba': 588,
#  'brindar': 589,
#  'fresco': 590,
#  'inversion': 591,
#  'terreno': 592,
#  'efectivamente': 593,
#  'medi': 594,
#  'acertado': 595,
#  'acertar': 596,
#  'descansada': 597,
#  'guante': 598,
#  'vida': 599,
#  'chevere': 600,
#  'nieto': 601,
#  'abullonada': 602,
#  'disfrutar': 603,
#  'fascinar': 604,
#  'temperatura': 605,
#  'eleccion': 606,
#  'maravilloso': 607,
#  'ecxelente': 608,
#  'centro': 609,
#  'ciudad': 610,
#  'mandar': 611,
#  'definitivamente': 612,
#  'igualmente': 613,
#  'aceptable': 614,
#  'siquiera': 615,
#  'pidar': 616,
#  'tenerla': 617,
#  'delgadito': 618,
#  'solicite': 619,
#  'descosio': 620,
#  'quimico': 621,
#  'debil': 622,
#  'mitad': 623,
#  'centimetro': 624,
#  'pq': 625,
#  'apariencia': 626,
#  'correa': 627,
#  'hombre': 628,
#  'lograr': 629,
#  'elegi': 630,
#  'devolucion': 631,
#  'actividad': 632,
#  'dueno': 633,
#  'elevado': 634,
#  'solicitud': 635,
#  '36': 636,
#  '37': 637,
#  'estampado': 638,
#  'ducha': 639,
#  'equivocar': 640,
#  'despego': 641,
#  'indicado': 642,
#  'sonar': 643,
#  'promocionar': 644,
#  'ventilacion': 645,
#  'bajo': 646,
#  'cansancio': 647,
#  'recien': 648,
#  'felpa': 649,
#  'duelar': 650,
#  'vivir': 651,
#  'raro': 652,
#  'usarla': 653,
#  'derecho': 654,
#  'recomendación': 655,
#  'lavado': 656,
#  'lavarla': 657,
#  'opción': 658,
#  'pies': 659,
#  'largo': 660,
#  'alcanzar': 661,
#  'vs': 662,
#  'gruesa': 663,
#  'zona': 664,
#  'hogar': 665,
#  'tenia': 666,
#  'camino': 667,
#  'comparacion': 668,
#  'tal': 669,
#  'pegar': 670,
#  'disenado': 671,
#  'don': 672,
#  'habiar': 673,
#  'entrada': 674,
#  'similar': 675,
#  'agregar': 676,
#  'delicado': 677,
#  'llamativo': 678,
#  'aire': 679,
#  'mojar': 680,
#  'exagerado': 681,
#  'fragil': 682,
#  'hebilla': 683,
#  'relativamente': 684,
#  'demar': 685,
#  'podiar': 686,
#  'calurosa': 687,
#  'deterioro': 688,
#  'error': 689,
#  'abrigan': 690,
#  'hermano': 691,
#  'bolsa': 692,
#  'lastimo': 693,
#  'volver': 694,
#  'descalzo': 695,
#  'pid': 696,
#  'antiresbalante': 697,
#  'pelar': 698,
#  'livián': 699,
#  'pelo': 700,
#  'ampol': 701,
#  'espacio': 702,
#  'necesario': 703,
#  'diferencia': 704,
#  'presentado': 705,
#  'calorosita': 706,
#  'my': 707,
#  'ensuciar': 708,
#  'nacional': 709,
#  'aspecto': 710,
#  'optimo': 711,
#  'guant': 712,
#  'mensaje': 713,
#  'rara': 714,
#  'deslizante': 715,
#  'mencionar': 716,
#  'recibido': 717,
#  'amplio': 718,
#  'probe': 719,
#  'tenio': 720,
#  'dolor': 721,
#  'sugiero': 722,
#  'bb': 723,
#  'ajusto': 724,
#  'depronto': 725,
#  'anunciado': 726,
#  'felicitación': 727,
#  'seguridad': 728,
#  'obsequio': 729,
#  'buenisimo': 730,
#  'termico': 731,
#  'coger': 732,
#  'confiable': 733,
#  'soportar': 734,
#  'hablar': 735,
#  'deseado': 736,
#  'abuelita': 737,
#  'nieta': 738,
#  'tomar': 739,
#  'chancleta': 740,
#  'amiga': 741,
#  'metio': 742,
#  'acabar': 743,
#  'mostrado': 744,
#  'considerar': 745,
#  'vibrante': 746,
#  'diabetico': 747,
#  'duda': 748,
#  'puntualidad': 749,
#  'abuelito': 750,
#  'sencillamente': 751,
#  'recomendadisimo': 752,
#  'seguire': 753,
#  'debi': 754,
#  'proteger': 755,
#  'descrito': 756,
#  'senti': 757,
#  'profucto': 758,
#  'disponible': 759,
#  'pedar': 760,
#  'supero': 761,
#  'comodamente': 762,
#  'comun': 763,
#  'durabl': 764,
#  'lucir': 765,
#  'suavecito': 766,
#  'especificado': 767,
#  'especialmente': 768,
#  'efectivo': 769,
#  'contratiempo': 770,
#  'importar': 771,
#  'pintada': 772,
#  'replica': 773,
#  'aplasto': 774,
#  'costosa': 775,
#  'imperfecto': 776,
#  'cocida': 777,
#  'continuo': 778,
#  'concuerdar': 779,
#  'lio': 780,
#  'mo': 781,
#  'holgado': 782,
#  'peligroso': 783,
#  'plata': 784,
#  'numeracion': 785,
#  'rapir': 786,
#  'exceso': 787,
#  'descosida': 788,
#  'regalarla': 789,
#  'correspondiar': 790,
#  'completar': 791,
#  'pintado': 792,
#  'favor': 793,
#  'principal': 794,
#  'mala': 795,
#  'rajar': 796,
#  'corregir': 797,
#  'especificar': 798,
#  'reducir': 799,
#  'oportunidad': 800,
#  'almacén': 801,
#  'pesos': 802,
#  'dibujo': 803,
#  'talleje': 804,
#  'paso': 805,
#  'safar': 806,
#  'area': 807,
#  'pareciar': 808,
#  'resbalir': 809,
#  'feo': 810,
#  'letra': 811,
#  'llevarla': 812,
#  'rapidez': 813,
#  'falta': 814,
#  'causar': 815,
#  'apoyo': 816,
#  'sencillo': 817,
#  'usandola': 818,
#  'quedariar': 819,
#  'agrado': 820,
#  'bano': 821,
#  'veniar': 822,
#  'rigida': 823,
#  'pi': 824,
#  'calcetín': 825,
#  'hinchado': 826,
#  'deliciós': 827,
#  'facilmente': 828,
#  'bajar': 829,
#  'escalera': 830,
#  'contacto': 831,
#  'triple': 832,
#  'encontre': 833,
#  'constante': 834,
#  'exageradamente': 835,
#  'revisen': 836,
#  'apliqu': 837,
#  'tallado': 838,
#  'envuelta': 839,
#  'simple': 840,
#  'y': 841,
#  'ralla': 842,
#  'apretadas': 843,
#  'marcar': 844,
#  'piel': 845,
#  'rango': 846,
#  'borde': 847,
#  'descoser': 848,
#  'escribi': 849,
#  'deform': 850,
#  'qu': 851,
#  'espero': 852,
#  'defecto': 853,
#  'proposito': 854,
#  'ambiente': 855,
#  'incomodos': 856,
#  'utilizo': 857,
#  'motosear': 858,
#  'ordenar': 859,
#  'terminación': 860,
#  'grandisima': 861,
#  'talle': 862,
#  '45': 863,
#  'lave': 864,
#  'especifico': 865,
#  'rosado': 866,
#  'actualizar': 867,
#  'inventario': 868,
#  'elijar': 869,
#  'prefierar': 870,
#  '46': 871,
#  'familiar': 872,
#  'apesar': 873,
#  'tallo': 874,
#  'muyyy': 875,
#  'alfombra': 876,
#  'tubo': 877,
#  'teniar': 878,
#  'batman': 879,
#  'restar': 880,
#  'sugeririar': 881,
#  'vista': 882,
#  'esfuerzo': 883,
#  'goma': 884,
#  'negro': 885,
#  'cliente': 886,
#  'sient': 887,
#  'informacion': 888,
#  'doblar': 889,
#  'actual': 890,
#  '42': 891,
#  'cerca': 892,
#  'aca': 893,
#  'talón': 894,
#  'melo': 895,
#  'senoro': 896,
#  'cabalidad': 897,
#  'xl': 898,
#  'desprender': 899,
#  'navidad': 900,
#  'gustario': 901,
#  'capellada': 902,
#  'quito': 903,
#  'logre': 904,
#  'tradicional': 905,
#  'deciar': 906,
#  'ubeír': 907,
#  'frente': 908,
#  'consejo': 909,
#  'relacionado': 910,
#  'esperario': 911,
#  'parecido': 912,
#  'claramente': 913,
#  'lavada': 914,
#  'observar': 915,
#  'adentro': 916,
#  'apoyar': 917,
#  'lindas': 918,
#  'constantemente': 919,
#  'abrigador': 920,
#  'protegido': 921,
#  'promocion': 922,
#  'huelar': 923,
#  'pegante': 924,
#  'negativo': 925,
#  'relajado': 926,
#  'oscuro': 927,
#  'prometido': 928,
#  'pendiente': 929,
#  'evaluar': 930,
#  'oreja': 931,
#  'fabrica': 932,
#  'comercio': 933,
#  'abullonado': 934,
#  'utilizado': 935,
#  'asfalto': 936,
#  'distinguir': 937,
#  'proporcionar': 938,
#  'ocasión': 939,
#  'v': 940,
#  'exterior': 941,
#  'mikey': 942,
#  'muneco': 943,
#  'utilacer': 944,
#  'construccion': 945,
#  'seguido': 946,
#  'adorar': 947,
#  'suelto': 948,
#  'abrigadoro': 949,
#  'deporte': 950,
#  'requerir': 951,
#  'cola': 952,
#  'anti': 953,
#  'cosida': 954,
#  'pegado': 955,
#  'maltratar': 956,
#  'mami': 957,
#  'requerido': 958,
#  'agarrir': 959,
#  'comportar': 960,
#  'penar': 961,
#  'regresar': 962,
#  'hinchar': 963,
#  'gruesito': 964,
#  'hormar': 965,
#  'cuadra': 966,
#  'cuadro': 967,
#  'rato': 968,
#  'estrecha': 969,
#  'comienzo': 970,
#  'acomoda': 971,
#  'acoplar': 972,
#  'mut': 973,
#  'simplemente': 974,
#  'peludita': 975,
#  'ma': 976,
#  'comodad': 977,
#  'estandar': 978,
#  'palabra': 979,
#  'distancia': 980,
#  'adecuar': 981,
#  'ala': 982,
#  'croc': 983,
#  'permanecer': 984,
#  'querio': 985,
#  'grandecita': 986,
#  'filtrar': 987,
#  'mela': 988,
#  're': 989,
#  'descansado': 990,
#  'sobrepeso': 991,
#  'demostrar': 992,
#  'encantada': 993,
#  'sorprendente': 994,
#  'puse': 995,
#  'fijar': 996,
#  'atractivo': 997,
#  'pa': 998,
#  'roca': 999,
#  'vacación': 1000,
#  ...}

# %%
tokenizer.texts_to_sequences(["MUY LINDAS LAS BABUCHA."])
# Out:
# [[1, 918, 1, 53]]

# %%
import numpy as np
from sklearn.model_selection import train_test_split

y = df["sentimiento_id"].values  # Asegúrate que está codificada como 0, 1, 2

# División estratificada
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
df["sentimiento_id"].value_counts()
# Out:
# sentimiento_id
# 1    4073
# 0     400
# Name: count, dtype: int64

# %%
print(X_test.shape)
print(y_test.shape)
print(X_train.shape)
print(y_train.shape)
# Out:
# (895, 50)
# (895,)
# (3578, 50)
# (3578,)

# %%
tokenizer.word_index
# Out:
# {'<OOV>': 1,
#  'excelente': 2,
#  'comoda': 3,
#  'talla': 4,
#  'comodo': 5,
#  'bonito': 6,
#  'super': 7,
#  'quedar': 8,
#  'material': 9,
#  'esperar': 10,
#  'lindo': 11,
#  'suave': 12,
#  'encantar': 13,
#  'perfecto': 14,
#  'precio': 15,
#  'recomendado': 16,
#  'pie': 17,
#  'suela': 18,
#  'recomeir': 19,
#  'foto': 20,
#  'gustar': 21,
#  'ver': 22,
#  'pedir': 23,
#  'justo': 24,
#  'pedi': 25,
#  'gracias': 26,
#  'pequena': 27,
#  'comprar': 28,
#  'él': 29,
#  'quedo': 30,
#  'pantufla': 31,
#  'diseno': 32,
#  'zapato': 33,
#  'hermosa': 34,
#  'regalo': 35,
#  'cumplir': 36,
#  'color': 37,
#  'gusto': 38,
#  'compra': 39,
#  'gracia': 40,
#  'bonita': 41,
#  'parecer': 42,
#  'pequeno': 43,
#  'medida': 44,
#  'satisfecho': 45,
#  'hermoso': 46,
#  'sentir': 47,
#  'casa': 48,
#  'caminar': 49,
#  'genial': 50,
#  'rapido': 51,
#  'esperado': 52,
#  'babucha': 53,
#  'imagen': 54,
#  'playa': 55,
#  'expectativa': 56,
#  'numero': 57,
#  'compre': 58,
#  'frio': 59,
#  'comodas': 60,
#  'exelente': 61,
#  'hijo': 62,
#  'tallar': 63,
#  'venir': 64,
#  'terminado': 65,
#  'pequén': 66,
#  'unico': 67,
#  'tener': 68,
#  'acorde': 69,
#  'acabado': 70,
#  'relacion': 71,
#  'liviana': 72,
#  'malo': 73,
#  'comodidad': 74,
#  'usar': 75,
#  'resistente': 76,
#  'feliz': 77,
#  'delgado': 78,
#  'q': 79,
#  '100': 80,
#  'cumplio': 81,
#  'resto': 82,
#  'necesitar': 83,
#  'duro': 84,
#  'facil': 85,
#  'descripcion': 86,
#  'tallaje': 87,
#  'persona': 88,
#  'arena': 89,
#  'ajustar': 90,
#  'salir': 91,
#  'tiempo': 92,
#  'realmente': 93,
#  'par': 94,
#  'nino': 95,
#  'normalmente': 96,
#  'chancla': 97,
#  'comprir': 98,
#  'normal': 99,
#  'confortabl': 100,
#  'piso': 101,
#  'llegar': 102,
#  'tocar': 103,
#  'preciso': 104,
#  'agua': 105,
#  'acolchada': 106,
#  'tamano': 107,
#  'caliente': 108,
#  'liviano': 109,
#  'hija': 110,
#  'espectacular': 111,
#  'espectativa': 112,
#  'calientita': 113,
#  'totalmente': 114,
#  'mes': 115,
#  'plantilla': 116,
#  'tabla': 117,
#  'calientica': 118,
#  'general': 119,
#  'cambiar': 120,
#  'rio': 121,
#  'corresponder': 122,
#  'sandalia': 123,
#  'exacto': 124,
#  'recomendable': 125,
#  'agradable': 126,
#  'practico': 127,
#  'problema': 128,
#  'antideslizante': 129,
#  'grueso': 130,
#  'funcion': 131,
#  'antideslizant': 132,
#  'contento': 133,
#  'elaborado': 134,
#  'calient': 135,
#  'semana': 136,
#  'calentar': 137,
#  'mostrar': 138,
#  'calzado': 139,
#  'adecuado': 140,
#  'andar': 141,
#  'correcto': 142,
#  'exactamente': 143,
#  'hecho': 144,
#  'util': 145,
#  'perfecta': 146,
#  'esposa': 147,
#  'servir': 148,
#  'ofrecer': 149,
#  'buscar': 150,
#  'calentita': 151,
#  'durar': 152,
#  'parecio': 153,
#  'quitar': 154,
#  'ideal': 155,
#  'danar': 156,
#  'funcionar': 157,
#  'guia': 158,
#  'forma': 159,
#  'costura': 160,
#  'publicacion': 161,
#  'detalle': 162,
#  'ajustado': 163,
#  'mantener': 164,
#  'madre': 165,
#  'romper': 166,
#  'deberiar': 167,
#  'suelar': 168,
#  'regalar': 169,
#  'valer': 170,
#  'encantado': 171,
#  'costo': 172,
#  'alto': 173,
#  'esposo': 174,
#  'regular': 175,
#  'tela': 176,
#  'aparecer': 177,
#  'poquito': 178,
#  'media': 179,
#  'horma': 180,
#  'estar': 181,
#  'duradero': 182,
#  'mama': 183,
#  'chever': 184,
#  'ir': 185,
#  'seguro': 186,
#  'calzar': 187,
#  'divina': 188,
#  'pena': 189,
#  'mar': 190,
#  'ancho': 191,
#  'calzo': 192,
#  'agarre': 193,
#  'bello': 194,
#  'despegar': 195,
#  'original': 196,
#  'utilizar': 197,
#  'costoso': 198,
#  'llevar': 199,
#  'espuma': 200,
#  'poder': 201,
#  'pensar': 202,
#  'faltar': 203,
#  'mejorar': 204,
#  'importante': 205,
#  'abrigada': 206,
#  'principio': 207,
#  'precioso': 208,
#  'igual': 209,
#  'hacer': 210,
#  'cambio': 211,
#  'comprado': 212,
#  'pense': 213,
#  'querer': 214,
#  'economica': 215,
#  'ser': 216,
#  'descansar': 217,
#  'descanso': 218,
#  'pagina': 219,
#  'clima': 220,
#  'bonitas': 221,
#  'diente': 222,
#  'interior': 223,
#  'beneficio': 224,
#  'marca': 225,
#  'poner': 226,
#  'deformar': 227,
#  'ningun': 228,
#  'cm': 229,
#  'caso': 230,
#  'modelo': 231,
#  'secar': 232,
#  'ano': 233,
#  'confeccion': 234,
#  'dar': 235,
#  'salio': 236,
#  'funcional': 237,
#  'seriar': 238,
#  'recomendar': 239,
#  'suavecita': 240,
#  'opcion': 241,
#  'confortable': 242,
#  'incomoda': 243,
#  'calza': 244,
#  'muchisimo': 245,
#  'barato': 246,
#  'habitual': 247,
#  'talon': 248,
#  'comentario': 249,
#  'recibi': 250,
#  'plastico': 251,
#  'acolchado': 252,
#  'dejar': 253,
#  'sensacion': 254,
#  'mejor': 255,
#  'linda': 256,
#  'haber': 257,
#  'deslizar': 258,
#  'reducido': 259,
#  'pasar': 260,
#  'recomendacion': 261,
#  'volverio': 262,
#  'describir': 263,
#  'confeccionado': 264,
#  'ok': 265,
#  'practica': 266,
#  'limpiar': 267,
#  'novia': 268,
#  'contentar': 269,
#  'publicidad': 270,
#  'olor': 271,
#  'especificación': 272,
#  'calle': 273,
#  'postura': 274,
#  'hora': 275,
#  'presentacion': 276,
#  'comprador': 277,
#  'zuela': 278,
#  'imaginar': 279,
#  'piedra': 280,
#  'recibir': 281,
#  'cuidado': 282,
#  'calida': 283,
#  'empeine': 284,
#  'papa': 285,
#  'fuerte': 286,
#  'momento': 287,
#  'queria': 288,
#  'seguir': 289,
#  'dema': 290,
#  'abrigadora': 291,
#  'lleno': 292,
#  'probar': 293,
#  'bordado': 294,
#  'padre': 295,
#  'colombiano': 296,
#  'interno': 297,
#  'inconveniente': 298,
#  'facilidad': 299,
#  'ojo': 300,
#  'telar': 301,
#  'estrecho': 302,
#  'traer': 303,
#  'chico': 304,
#  'desgastar': 305,
#  'orma': 306,
#  'objetivo': 307,
#  'entrar': 308,
#  'deberio': 309,
#  'pesado': 310,
#  'confort': 311,
#  'tipo': 312,
#  'deber': 313,
#  'planta': 314,
#  'soler': 315,
#  'relleno': 316,
#  'durabilidad': 317,
#  'viaje': 318,
#  'resultar': 319,
#  'meter': 320,
#  'sugerir': 321,
#  'calientito': 322,
#  'elegante': 323,
#  'necesidad': 324,
#  'calientico': 325,
#  'sorprender': 326,
#  'fotografia': 327,
#  'estilo': 328,
#  'bn': 329,
#  'nina': 330,
#  'superar': 331,
#  'bebe': 332,
#  'extremadamente': 333,
#  'porq': 334,
#  'realidad': 335,
#  'responder': 336,
#  'pisar': 337,
#  'devolver': 338,
#  'ejemplo': 339,
#  'caer': 340,
#  'punto': 341,
#  'descocio': 342,
#  'terminar': 343,
#  'cubrir': 344,
#  'cansar': 345,
#  'flexible': 346,
#  'valor': 347,
#  'empezar': 348,
#  'referencia': 349,
#  'fino': 350,
#  'piscina': 351,
#  'yo': 352,
#  'base': 353,
#  'ofertado': 354,
#  'comodos': 355,
#  'molestar': 356,
#  'caracteristica': 357,
#  'fiel': 358,
#  'opinion': 359,
#  'permitir': 360,
#  'compren': 361,
#  'perfectamente': 362,
#  'medir': 363,
#  'evitar': 364,
#  'rico': 365,
#  'lavar': 366,
#  'queriar': 367,
#  'conforme': 368,
#  'amar': 369,
#  'articulo': 370,
#  'pintura': 371,
#  'pesimo': 372,
#  'rigido': 373,
#  'caro': 374,
#  'coincidir': 375,
#  'aguantar': 376,
#  'sacar': 377,
#  'solicitado': 378,
#  'superficie': 379,
#  'real': 380,
#  'suponer': 381,
#  'encontrar': 382,
#  'superior': 383,
#  'usual': 384,
#  'dedo': 385,
#  'calor': 386,
#  'chica': 387,
#  'puntual': 388,
#  '38': 389,
#  'pidio': 390,
#  'tenis': 391,
#  'veiar': 392,
#  'x': 393,
#  'esperabar': 394,
#  'garra': 395,
#  '40': 396,
#  'usualmente': 397,
#  '41': 398,
#  'maravilla': 399,
#  'calidad': 400,
#  'cumplimiento': 401,
#  'secado': 402,
#  'anuncio': 403,
#  'estupendo': 404,
#  'notar': 405,
#  'rapidamente': 406,
#  'increible': 407,
#  'preciosa': 408,
#  'comprare': 409,
#  'escoger': 410,
#  'ame': 411,
#  'pareja': 412,
#  'compro': 413,
#  'producto': 414,
#  'horrible': 415,
#  'ordinario': 416,
#  'termino': 417,
#  'decir': 418,
#  'supremamente': 419,
#  'ortopedica': 420,
#  'oler': 421,
#  'abrir': 422,
#  'incomodo': 423,
#  'liso': 424,
#  'sentido': 425,
#  'anunciar': 426,
#  'blanco': 427,
#  'punta': 428,
#  'mano': 429,
#  'noche': 430,
#  'prometer': 431,
#  'claro': 432,
#  'delgar': 433,
#  'volveria': 434,
#  'experiencia': 435,
#  'agrandar': 436,
#  'lado': 437,
#  'usando': 438,
#  'adulto': 439,
#  'respuesta': 440,
#  'suficiente': 441,
#  'apretado': 442,
#  'cuero': 443,
#  'desear': 444,
#  'rompio': 445,
#  'suelo': 446,
#  'dificil': 447,
#  'cerrado': 448,
#  'lastimar': 449,
#  'economico': 450,
#  'revisar': 451,
#  'cosa': 452,
#  'ajuste': 453,
#  'tobillo': 454,
#  'sobrina': 455,
#  'indicar': 456,
#  'pantunfla': 457,
#  'apretar': 458,
#  'peso': 459,
#  'durir': 460,
#  '39': 461,
#  'abrigado': 462,
#  'divino': 463,
#  'puesto': 464,
#  'angosto': 465,
#  'plano': 466,
#  'ayudar': 467,
#  'estetico': 468,
#  'colombia': 469,
#  'gris': 470,
#  'execelente': 471,
#  'firme': 472,
#  'recibio': 473,
#  'corto': 474,
#  'serio': 475,
#  'pagar': 476,
#  'especial': 477,
#  'satisfaccion': 478,
#  'bogota': 479,
#  'l': 480,
#  'miedo': 481,
#  'condición': 482,
#  'disenada': 483,
#  'materia': 484,
#  'alguien': 485,
#  'pedirla': 486,
#  'full': 487,
#  'apropiado': 488,
#  'hermana': 489,
#  'fantastica': 490,
#  'excepcional': 491,
#  'cumplido': 492,
#  'comida': 493,
#  'sobrino': 494,
#  'correr': 495,
#  'descoseír': 496,
#  'subir': 497,
#  'menor': 498,
#  'enganós': 499,
#  'perder': 500,
#  'dinero': 501,
#  'novio': 502,
#  'devolvi': 503,
#  'pese': 504,
#  'terrible': 505,
#  'caber': 506,
#  'comprarla': 507,
#  'usado': 508,
#  'pen': 509,
#  'empaque': 510,
#  'garantia': 511,
#  'demas': 512,
#  'descoceír': 513,
#  'abajo': 514,
#  'dano': 515,
#  'ampolla': 516,
#  'negra': 517,
#  'mojado': 518,
#  'anchas': 519,
#  'generar': 520,
#  'trabajo': 521,
#  'caucho': 522,
#  'completamente': 523,
#  'cordón': 524,
#  'resulto': 525,
#  'fria': 526,
#  'medio': 527,
#  'izquierdo': 528,
#  'lavadora': 529,
#  'suavidad': 530,
#  'mover': 531,
#  'tender': 532,
#  'soltar': 533,
#  'mujer': 534,
#  'pequenar': 535,
#  'larga': 536,
#  'lastimosamente': 537,
#  'aparte': 538,
#  'avisar': 539,
#  'sudar': 540,
#  'calido': 541,
#  'diario': 542,
#  'resbalar': 543,
#  'inicio': 544,
#  'azul': 545,
#  'ingresar': 546,
#  'blando': 547,
#  'volverir': 548,
#  'verificar': 549,
#  'inferior': 550,
#  'proteccion': 551,
#  'recomendariar': 552,
#  'textura': 553,
#  'resistencia': 554,
#  'san': 555,
#  'andr': 556,
#  'ligero': 557,
#  'perfeccion': 558,
#  'tema': 559,
#  'blandita': 560,
#  'peluche': 561,
#  'cerdito': 562,
#  'esteticamente': 563,
#  'adicional': 564,
#  'camine': 565,
#  'nube': 566,
#  'ormar': 567,
#  'belleza': 568,
#  'solicitar': 569,
#  'fina': 570,
#  'cheverar': 571,
#  'gustariar': 572,
#  'terminacion': 573,
#  'calir': 574,
#  'bue': 575,
#  'sugerencia': 576,
#  'justa': 577,
#  'fabricado': 578,
#  'zapatilla': 579,
#  'escogi': 580,
#  'pulido': 581,
#  'tierno': 582,
#  'colocar': 583,
#  'trabajar': 584,
#  'd': 585,
#  'queja': 586,
#  'caminata': 587,
#  'prueba': 588,
#  'brindar': 589,
#  'fresco': 590,
#  'inversion': 591,
#  'terreno': 592,
#  'efectivamente': 593,
#  'medi': 594,
#  'acertado': 595,
#  'acertar': 596,
#  'descansada': 597,
#  'guante': 598,
#  'vida': 599,
#  'chevere': 600,
#  'nieto': 601,
#  'abullonada': 602,
#  'disfrutar': 603,
#  'fascinar': 604,
#  'temperatura': 605,
#  'eleccion': 606,
#  'maravilloso': 607,
#  'ecxelente': 608,
#  'centro': 609,
#  'ciudad': 610,
#  'mandar': 611,
#  'definitivamente': 612,
#  'igualmente': 613,
#  'aceptable': 614,
#  'siquiera': 615,
#  'pidar': 616,
#  'tenerla': 617,
#  'delgadito': 618,
#  'solicite': 619,
#  'descosio': 620,
#  'quimico': 621,
#  'debil': 622,
#  'mitad': 623,
#  'centimetro': 624,
#  'pq': 625,
#  'apariencia': 626,
#  'correa': 627,
#  'hombre': 628,
#  'lograr': 629,
#  'elegi': 630,
#  'devolucion': 631,
#  'actividad': 632,
#  'dueno': 633,
#  'elevado': 634,
#  'solicitud': 635,
#  '36': 636,
#  '37': 637,
#  'estampado': 638,
#  'ducha': 639,
#  'equivocar': 640,
#  'despego': 641,
#  'indicado': 642,
#  'sonar': 643,
#  'promocionar': 644,
#  'ventilacion': 645,
#  'bajo': 646,
#  'cansancio': 647,
#  'recien': 648,
#  'felpa': 649,
#  'duelar': 650,
#  'vivir': 651,
#  'raro': 652,
#  'usarla': 653,
#  'derecho': 654,
#  'recomendación': 655,
#  'lavado': 656,
#  'lavarla': 657,
#  'opción': 658,
#  'pies': 659,
#  'largo': 660,
#  'alcanzar': 661,
#  'vs': 662,
#  'gruesa': 663,
#  'zona': 664,
#  'hogar': 665,
#  'tenia': 666,
#  'camino': 667,
#  'comparacion': 668,
#  'tal': 669,
#  'pegar': 670,
#  'disenado': 671,
#  'don': 672,
#  'habiar': 673,
#  'entrada': 674,
#  'similar': 675,
#  'agregar': 676,
#  'delicado': 677,
#  'llamativo': 678,
#  'aire': 679,
#  'mojar': 680,
#  'exagerado': 681,
#  'fragil': 682,
#  'hebilla': 683,
#  'relativamente': 684,
#  'demar': 685,
#  'podiar': 686,
#  'calurosa': 687,
#  'deterioro': 688,
#  'error': 689,
#  'abrigan': 690,
#  'hermano': 691,
#  'bolsa': 692,
#  'lastimo': 693,
#  'volver': 694,
#  'descalzo': 695,
#  'pid': 696,
#  'antiresbalante': 697,
#  'pelar': 698,
#  'livián': 699,
#  'pelo': 700,
#  'ampol': 701,
#  'espacio': 702,
#  'necesario': 703,
#  'diferencia': 704,
#  'presentado': 705,
#  'calorosita': 706,
#  'my': 707,
#  'ensuciar': 708,
#  'nacional': 709,
#  'aspecto': 710,
#  'optimo': 711,
#  'guant': 712,
#  'mensaje': 713,
#  'rara': 714,
#  'deslizante': 715,
#  'mencionar': 716,
#  'recibido': 717,
#  'amplio': 718,
#  'probe': 719,
#  'tenio': 720,
#  'dolor': 721,
#  'sugiero': 722,
#  'bb': 723,
#  'ajusto': 724,
#  'depronto': 725,
#  'anunciado': 726,
#  'felicitación': 727,
#  'seguridad': 728,
#  'obsequio': 729,
#  'buenisimo': 730,
#  'termico': 731,
#  'coger': 732,
#  'confiable': 733,
#  'soportar': 734,
#  'hablar': 735,
#  'deseado': 736,
#  'abuelita': 737,
#  'nieta': 738,
#  'tomar': 739,
#  'chancleta': 740,
#  'amiga': 741,
#  'metio': 742,
#  'acabar': 743,
#  'mostrado': 744,
#  'considerar': 745,
#  'vibrante': 746,
#  'diabetico': 747,
#  'duda': 748,
#  'puntualidad': 749,
#  'abuelito': 750,
#  'sencillamente': 751,
#  'recomendadisimo': 752,
#  'seguire': 753,
#  'debi': 754,
#  'proteger': 755,
#  'descrito': 756,
#  'senti': 757,
#  'profucto': 758,
#  'disponible': 759,
#  'pedar': 760,
#  'supero': 761,
#  'comodamente': 762,
#  'comun': 763,
#  'durabl': 764,
#  'lucir': 765,
#  'suavecito': 766,
#  'especificado': 767,
#  'especialmente': 768,
#  'efectivo': 769,
#  'contratiempo': 770,
#  'importar': 771,
#  'pintada': 772,
#  'replica': 773,
#  'aplasto': 774,
#  'costosa': 775,
#  'imperfecto': 776,
#  'cocida': 777,
#  'continuo': 778,
#  'concuerdar': 779,
#  'lio': 780,
#  'mo': 781,
#  'holgado': 782,
#  'peligroso': 783,
#  'plata': 784,
#  'numeracion': 785,
#  'rapir': 786,
#  'exceso': 787,
#  'descosida': 788,
#  'regalarla': 789,
#  'correspondiar': 790,
#  'completar': 791,
#  'pintado': 792,
#  'favor': 793,
#  'principal': 794,
#  'mala': 795,
#  'rajar': 796,
#  'corregir': 797,
#  'especificar': 798,
#  'reducir': 799,
#  'oportunidad': 800,
#  'almacén': 801,
#  'pesos': 802,
#  'dibujo': 803,
#  'talleje': 804,
#  'paso': 805,
#  'safar': 806,
#  'area': 807,
#  'pareciar': 808,
#  'resbalir': 809,
#  'feo': 810,
#  'letra': 811,
#  'llevarla': 812,
#  'rapidez': 813,
#  'falta': 814,
#  'causar': 815,
#  'apoyo': 816,
#  'sencillo': 817,
#  'usandola': 818,
#  'quedariar': 819,
#  'agrado': 820,
#  'bano': 821,
#  'veniar': 822,
#  'rigida': 823,
#  'pi': 824,
#  'calcetín': 825,
#  'hinchado': 826,
#  'deliciós': 827,
#  'facilmente': 828,
#  'bajar': 829,
#  'escalera': 830,
#  'contacto': 831,
#  'triple': 832,
#  'encontre': 833,
#  'constante': 834,
#  'exageradamente': 835,
#  'revisen': 836,
#  'apliqu': 837,
#  'tallado': 838,
#  'envuelta': 839,
#  'simple': 840,
#  'y': 841,
#  'ralla': 842,
#  'apretadas': 843,
#  'marcar': 844,
#  'piel': 845,
#  'rango': 846,
#  'borde': 847,
#  'descoser': 848,
#  'escribi': 849,
#  'deform': 850,
#  'qu': 851,
#  'espero': 852,
#  'defecto': 853,
#  'proposito': 854,
#  'ambiente': 855,
#  'incomodos': 856,
#  'utilizo': 857,
#  'motosear': 858,
#  'ordenar': 859,
#  'terminación': 860,
#  'grandisima': 861,
#  'talle': 862,
#  '45': 863,
#  'lave': 864,
#  'especifico': 865,
#  'rosado': 866,
#  'actualizar': 867,
#  'inventario': 868,
#  'elijar': 869,
#  'prefierar': 870,
#  '46': 871,
#  'familiar': 872,
#  'apesar': 873,
#  'tallo': 874,
#  'muyyy': 875,
#  'alfombra': 876,
#  'tubo': 877,
#  'teniar': 878,
#  'batman': 879,
#  'restar': 880,
#  'sugeririar': 881,
#  'vista': 882,
#  'esfuerzo': 883,
#  'goma': 884,
#  'negro': 885,
#  'cliente': 886,
#  'sient': 887,
#  'informacion': 888,
#  'doblar': 889,
#  'actual': 890,
#  '42': 891,
#  'cerca': 892,
#  'aca': 893,
#  'talón': 894,
#  'melo': 895,
#  'senoro': 896,
#  'cabalidad': 897,
#  'xl': 898,
#  'desprender': 899,
#  'navidad': 900,
#  'gustario': 901,
#  'capellada': 902,
#  'quito': 903,
#  'logre': 904,
#  'tradicional': 905,
#  'deciar': 906,
#  'ubeír': 907,
#  'frente': 908,
#  'consejo': 909,
#  'relacionado': 910,
#  'esperario': 911,
#  'parecido': 912,
#  'claramente': 913,
#  'lavada': 914,
#  'observar': 915,
#  'adentro': 916,
#  'apoyar': 917,
#  'lindas': 918,
#  'constantemente': 919,
#  'abrigador': 920,
#  'protegido': 921,
#  'promocion': 922,
#  'huelar': 923,
#  'pegante': 924,
#  'negativo': 925,
#  'relajado': 926,
#  'oscuro': 927,
#  'prometido': 928,
#  'pendiente': 929,
#  'evaluar': 930,
#  'oreja': 931,
#  'fabrica': 932,
#  'comercio': 933,
#  'abullonado': 934,
#  'utilizado': 935,
#  'asfalto': 936,
#  'distinguir': 937,
#  'proporcionar': 938,
#  'ocasión': 939,
#  'v': 940,
#  'exterior': 941,
#  'mikey': 942,
#  'muneco': 943,
#  'utilacer': 944,
#  'construccion': 945,
#  'seguido': 946,
#  'adorar': 947,
#  'suelto': 948,
#  'abrigadoro': 949,
#  'deporte': 950,
#  'requerir': 951,
#  'cola': 952,
#  'anti': 953,
#  'cosida': 954,
#  'pegado': 955,
#  'maltratar': 956,
#  'mami': 957,
#  'requerido': 958,
#  'agarrir': 959,
#  'comportar': 960,
#  'penar': 961,
#  'regresar': 962,
#  'hinchar': 963,
#  'gruesito': 964,
#  'hormar': 965,
#  'cuadra': 966,
#  'cuadro': 967,
#  'rato': 968,
#  'estrecha': 969,
#  'comienzo': 970,
#  'acomoda': 971,
#  'acoplar': 972,
#  'mut': 973,
#  'simplemente': 974,
#  'peludita': 975,
#  'ma': 976,
#  'comodad': 977,
#  'estandar': 978,
#  'palabra': 979,
#  'distancia': 980,
#  'adecuar': 981,
#  'ala': 982,
#  'croc': 983,
#  'permanecer': 984,
#  'querio': 985,
#  'grandecita': 986,
#  'filtrar': 987,
#  'mela': 988,
#  're': 989,
#  'descansado': 990,
#  'sobrepeso': 991,
#  'demostrar': 992,
#  'encantada': 993,
#  'sorprendente': 994,
#  'puse': 995,
#  'fijar': 996,
#  'atractivo': 997,
#  'pa': 998,
#  'roca': 999,
#  'vacación': 1000,
#  ...}

# %% [markdown]
# ### Modelado

# %%
# 1. Importar librerías
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.optimizers import Adam  # o puedes usar SGD si quieres

# %%
# 2. Hiperparámetros
MAX_NUM_WORDS = 10000        # Tamaño del vocabulario
MAX_SEQUENCE_LENGTH = 50     # Longitud máxima de secuencias
EMBEDDING_DIM = 100          # Dimensión del vector de embedding
NUM_CLASSES = 2             # Salida: negativo, neutro, positivo

# %%
# 3. Definir el modelo CNN
model = Sequential([
    Embedding(input_dim=MAX_NUM_WORDS, output_dim=EMBEDDING_DIM, input_length=MAX_SEQUENCE_LENGTH),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dense(NUM_CLASSES, activation='sigmoid')  # Salida multiclase
])

# %%
# 4. Compilar el modelo
model.compile(
    optimizer=Adam(),  # puedes cambiar a SGD() si lo deseas
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Resumen del modelo
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 50, 100)           1000000
#
#  conv1d_5 (Conv1D)           (None, 46, 128)           64128
#
#  global_max_pooling1d_5 (Glo  (None, 128)              0
#  balMaxPooling1D)
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 1,072,514
# Trainable params: 1,072,514
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 5. Entrenar el modelo
history = model.fit(
    X_train, y_train,
    epochs=25,
    batch_size=23,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/25
# 156/156 [==============================] - 2s 9ms/step - loss: 0.2968 - accuracy: 0.9092 - val_loss: 0.2230 - val_accuracy: 0.9106
# Epoch 2/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.1706 - accuracy: 0.9343 - val_loss: 0.2325 - val_accuracy: 0.8994
# Epoch 3/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0936 - accuracy: 0.9693 - val_loss: 0.2946 - val_accuracy: 0.9028
# Epoch 4/25
# 156/156 [==============================] - 1s 9ms/step - loss: 0.0621 - accuracy: 0.9796 - val_loss: 0.3423 - val_accuracy: 0.8972
# Epoch 5/25
# 156/156 [==============================] - 1s 9ms/step - loss: 0.0459 - accuracy: 0.9877 - val_loss: 0.3895 - val_accuracy: 0.9039
# Epoch 6/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0376 - accuracy: 0.9894 - val_loss: 0.4176 - val_accuracy: 0.9039
# Epoch 7/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0335 - accuracy: 0.9894 - val_loss: 0.4400 - val_accuracy: 0.9061
# Epoch 8/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0303 - accuracy: 0.9905 - val_loss: 0.5085 - val_accuracy: 0.9117
# Epoch 9/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0271 - accuracy: 0.9902 - val_loss: 0.5348 - val_accuracy: 0.9039
# Epoch 10/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0263 - accuracy: 0.9902 - val_loss: 0.5616 - val_accuracy: 0.9006
# Epoch 11/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0249 - accuracy: 0.9925 - val_loss: 0.6211 - val_accuracy: 0.9106
# Epoch 12/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0271 - accuracy: 0.9922 - val_loss: 0.6398 - val_accuracy: 0.9106
# Epoch 13/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0259 - accuracy: 0.9925 - val_loss: 0.6632 - val_accuracy: 0.9117
# Epoch 14/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0256 - accuracy: 0.9927 - val_loss: 0.7140 - val_accuracy: 0.9039
# Epoch 15/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0209 - accuracy: 0.9936 - val_loss: 0.8159 - val_accuracy: 0.9151
# Epoch 16/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0256 - accuracy: 0.9919 - val_loss: 0.7416 - val_accuracy: 0.9106
# Epoch 17/25
# 156/156 [==============================] - 1s 7ms/step - loss: 0.0198 - accuracy: 0.9925 - val_loss: 0.7601 - val_accuracy: 0.9095
# Epoch 18/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.7804 - val_accuracy: 0.9050
# Epoch 19/25
# 156/156 [==============================] - 1s 7ms/step - loss: 0.0202 - accuracy: 0.9936 - val_loss: 0.7824 - val_accuracy: 0.9061
# Epoch 20/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0246 - accuracy: 0.9927 - val_loss: 0.8106 - val_accuracy: 0.9073
# Epoch 21/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.8849 - val_accuracy: 0.9128
# Epoch 22/25
# 156/156 [==============================] - 1s 9ms/step - loss: 0.0176 - accuracy: 0.9939 - val_loss: 0.9006 - val_accuracy: 0.9140
# Epoch 23/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0190 - accuracy: 0.9950 - val_loss: 0.8847 - val_accuracy: 0.9095
# Epoch 24/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0161 - accuracy: 0.9958 - val_loss: 0.9553 - val_accuracy: 0.9039
# Epoch 25/25
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0226 - accuracy: 0.9925 - val_loss: 0.9833 - val_accuracy: 0.9017

# %%
# 6. Evaluar desempeño
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Loss: {loss:.4f} - Accuracy: {accuracy:.4f}")
# Out:
# 28/28 [==============================] - 0s 2ms/step - loss: 0.9833 - accuracy: 0.9017
# Loss: 0.9833 - Accuracy: 0.9017

# %%
# ACCURACY
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por Época')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid(True)
plt.show()

# LOSS
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida (Loss) por Época')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Variacion 2

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from sklearn.utils.class_weight import compute_class_weight

# %%
# 1. Hiperparámetros
MAX_NUM_WORDS = 10000        # Tamaño del vocabulario
MAX_SEQUENCE_LENGTH = 50     # Longitud máxima de secuencias
EMBEDDING_DIM = 100          # Tamaño del embedding
NUM_CLASSES = 2              # Negativo, Neutro, Positivo

# 2. Calcular pesos de clase (si hay desbalance)
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))

# 3. Callback de early stopping
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=7,
    restore_best_weights=True
)

# 4. Definición del modelo
model = Sequential([
    Embedding(input_dim=MAX_NUM_WORDS, output_dim=EMBEDDING_DIM, input_length=MAX_SEQUENCE_LENGTH),
    Conv1D(filters=64, kernel_size=8, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.5),
    Dense(32, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='sigmoid')  # Salida binaria
])

# 5. Compilación
model.compile(
    optimizer=Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 6. Entrenamiento
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=28,
    validation_data=(X_test, y_test),
    class_weight=class_weights,
    callbacks=[early_stop]
)

# 7. Evaluación final
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Evaluación final → Loss: {loss:.4f} - Accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/50
# 128/128 [==============================] - 2s 9ms/step - loss: 0.9111 - accuracy: 0.6434 - val_loss: 0.7055 - val_accuracy: 0.7944
# Epoch 2/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.5787 - accuracy: 0.7764 - val_loss: 0.4243 - val_accuracy: 0.8492
# Epoch 3/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.3753 - accuracy: 0.8874 - val_loss: 0.3928 - val_accuracy: 0.8860
# Epoch 4/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.2712 - accuracy: 0.9441 - val_loss: 0.4695 - val_accuracy: 0.8480
# Epoch 5/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.2173 - accuracy: 0.9505 - val_loss: 0.3916 - val_accuracy: 0.8849
# Epoch 6/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.1932 - accuracy: 0.9603 - val_loss: 0.3491 - val_accuracy: 0.8983
# Epoch 7/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.1630 - accuracy: 0.9642 - val_loss: 0.3516 - val_accuracy: 0.9050
# Epoch 8/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.1389 - accuracy: 0.9788 - val_loss: 0.4343 - val_accuracy: 0.8704
# Epoch 9/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.1308 - accuracy: 0.9748 - val_loss: 0.3973 - val_accuracy: 0.8994
# Epoch 10/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.1151 - accuracy: 0.9824 - val_loss: 0.4187 - val_accuracy: 0.8927
# Epoch 11/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.1015 - accuracy: 0.9832 - val_loss: 0.4287 - val_accuracy: 0.9039
# Epoch 12/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.1135 - accuracy: 0.9785 - val_loss: 0.4265 - val_accuracy: 0.8860
# Epoch 13/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.1006 - accuracy: 0.9804 - val_loss: 0.4641 - val_accuracy: 0.8883
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3491 - accuracy: 0.8983
# Evaluación final → Loss: 0.3491 - Accuracy: 0.8983

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.plot(history.history['accuracy'], label='Entrenamiento', color='dodgerblue')
plt.plot(history.history['val_accuracy'], label='Validación', color='darkorange')
plt.title('Precisión por Época')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.plot(history.history['loss'], label='Entrenamiento', color='dodgerblue')
plt.plot(history.history['val_loss'], label='Validación', color='darkorange')
plt.title('Pérdida (Loss) por Época')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
# Obtener predicciones del modelo
y_pred_probs = model.predict(X_test)
y_pred = y_pred_probs.argmax(axis=1)  # Elegir la clase con mayor probabilidad

# Nombres de clases (ajústalos si tienes etiquetas personalizadas)
target_names = ['Negativo', 'Positivo']

# accuracy

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

# Reporte de clasificación
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred, target_names=target_names))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

# Visualización de la matriz
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.title("Matriz de Confusión")
#plt.tight_layout()
plt.show()
# Out:
# 28/28 [==============================] - 0s 2ms/step
# Accuracy: 0.8983
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#     Negativo       0.44      0.49      0.46        80
#     Positivo       0.95      0.94      0.94       815
#
#     accuracy                           0.90       895
#    macro avg       0.69      0.71      0.70       895
# weighted avg       0.90      0.90      0.90       895

# %%
class_weights
# Out:
# {0: 5.590625, 1: 0.549109883364027}

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Variacion oversampling

# %%
# ────────────────────────────────────────────────
# 1. Librerías necesarias
import numpy as np
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# ────────────────────────────────────────────────
# 2. Hiperparámetros
MAX_NUM_WORDS = 10000
MAX_SEQUENCE_LENGTH = 50
EMBEDDING_DIM = 100
NUM_CLASSES = 2  # Negativo, Positivo
NUM_EPOCHS = 25

# %%
# ────────────────────────────────────────────────
# 3. Oversampling SOLO al set de entrenamiento
ros = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

print("✔ Distribución original:", Counter(y_train))
print("✔ Distribución balanceada:", Counter(y_train_resampled))
# Out:
# ✔ Distribución original: Counter({1: 3258, 0: 320})
# ✔ Distribución balanceada: Counter({1: 3258, 0: 3258})

# %%
# ────────────────────────────────────────────────
# 4. Callback de EarlyStopping
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# ────────────────────────────────────────────────
# 5. Modelo CNN
model = Sequential([
    Embedding(input_dim=MAX_NUM_WORDS, output_dim=EMBEDDING_DIM, input_length=MAX_SEQUENCE_LENGTH),
    Conv1D(filters=64, kernel_size=5, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.5),
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='sigmoid')  # Salida binaria
])

# ────────────────────────────────────────────────
# 6. Compilación
model.compile(
    optimizer=Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# ────────────────────────────────────────────────
# 7. Entrenamiento
history = model.fit(
    X_train_resampled, y_train_resampled,
    epochs=NUM_EPOCHS,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/25
# 204/204 [==============================] - 2s 9ms/step - loss: 0.5208 - accuracy: 0.7606 - val_loss: 0.3186 - val_accuracy: 0.9017
# Epoch 2/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.2005 - accuracy: 0.9440 - val_loss: 0.3637 - val_accuracy: 0.9106
# Epoch 3/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.1184 - accuracy: 0.9699 - val_loss: 0.4554 - val_accuracy: 0.9006
# Epoch 4/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.0906 - accuracy: 0.9776 - val_loss: 0.5053 - val_accuracy: 0.9073
# Epoch 5/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.0803 - accuracy: 0.9814 - val_loss: 0.5609 - val_accuracy: 0.9028
# Epoch 6/25
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0734 - accuracy: 0.9820 - val_loss: 0.6038 - val_accuracy: 0.9039

# %%
# ────────────────────────────────────────────────
# 8. Evaluación
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\n📊 Evaluación final ➜ Loss: {loss:.4f} - Accuracy: {accuracy:.4f}")

# ────────────────────────────────────────────────
# 9. Reporte y Matriz de Confusión
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

print("\n📋 Reporte de clasificación:")
print(classification_report(y_test, y_pred_classes, digits=2))

print("\n🧩 Matriz de Confusión:")
print(confusion_matrix(y_test, y_pred_classes))

# ────────────────────────────────────────────────
# 10. Gráficas de entrenamiento
plt.figure(figsize=(10, 4))

# Precisión
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por Época')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()

# Pérdida
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida (Loss) por Época')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3186 - accuracy: 0.9017
#
# 📊 Evaluación final ➜ Loss: 0.3186 - Accuracy: 0.9017
# 28/28 [==============================] - 0s 2ms/step
#
# 📋 Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0       0.46      0.55      0.50        80
#            1       0.95      0.94      0.95       815
#
#     accuracy                           0.90       895
#    macro avg       0.71      0.74      0.72       895
# weighted avg       0.91      0.90      0.91       895
#
#
# 🧩 Matriz de Confusión:
# [[ 44  36]
#  [ 52 763]]

# %%
from imblearn.over_sampling import SMOTE

# %%
# División train-test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Aplicar SMOTE (requiere 2D arrays y etiquetas codificadas como enteros)
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
# visualizar las nuevas clases.
Counter(y_train_resampled)
# Out:
# Counter({1: 3258, 0: 3258})

# %%
# Calcular pesos de clase (opcional si ya equilibraste con SMOTE)
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train_resampled), y=y_train_resampled)
class_weights = dict(enumerate(class_weights))

# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Modelo CNN
model = Sequential([
    Embedding(input_dim=MAX_NUM_WORDS, output_dim=EMBEDDING_DIM, input_length=MAX_SEQUENCE_LENGTH),
    Conv1D(filters=64, kernel_size=5, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.5),
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='sigmoid')  # Salida binaria
])
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Entrenar
history = model.fit(
    X_train_resampled, y_train_resampled,
    epochs=25,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stop]
)

# Evaluar
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\n✅ Evaluación final ➜ Loss: {loss:.4f} - Accuracy: {accuracy:.4f}")

# Clasificación y matriz
y_pred = model.predict(X_test).argmax(axis=1)
print("\n📊 Reporte de clasificación:")
print(classification_report(y_test, y_pred))
print("\n🧮 Matriz de Confusión:")
print(confusion_matrix(y_test, y_pred))

# Gráficas
plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por Época')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida (Loss) por Época')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/25
# 204/204 [==============================] - 2s 9ms/step - loss: 0.6546 - accuracy: 0.6535 - val_loss: 0.6474 - val_accuracy: 0.6905
# Epoch 2/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.4743 - accuracy: 0.8036 - val_loss: 0.4544 - val_accuracy: 0.8313
# Epoch 3/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.3537 - accuracy: 0.8654 - val_loss: 0.5490 - val_accuracy: 0.8168
# Epoch 4/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.2932 - accuracy: 0.8941 - val_loss: 0.5130 - val_accuracy: 0.8291
# Epoch 5/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.2394 - accuracy: 0.9174 - val_loss: 0.7128 - val_accuracy: 0.8045
# Epoch 6/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.2058 - accuracy: 0.9259 - val_loss: 0.6466 - val_accuracy: 0.8268
# Epoch 7/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.1855 - accuracy: 0.9374 - val_loss: 0.7411 - val_accuracy: 0.8179
# Epoch 8/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.1664 - accuracy: 0.9455 - val_loss: 0.8817 - val_accuracy: 0.8089
# Epoch 9/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.1490 - accuracy: 0.9515 - val_loss: 0.8639 - val_accuracy: 0.8257
# Epoch 10/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.1334 - accuracy: 0.9572 - val_loss: 0.9284 - val_accuracy: 0.8201
# Epoch 11/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.1290 - accuracy: 0.9587 - val_loss: 1.0489 - val_accuracy: 0.8022
# Epoch 12/25
# 204/204 [==============================] - 2s 8ms/step - loss: 0.1241 - accuracy: 0.9599 - val_loss: 1.0976 - val_accuracy: 0.8168
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4544 - accuracy: 0.8313
#
# ✅ Evaluación final ➜ Loss: 0.4544 - Accuracy: 0.8313
# 28/28 [==============================] - 0s 2ms/step
#
# 📊 Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0       0.29      0.62      0.40        80
#            1       0.96      0.85      0.90       815
#
#     accuracy                           0.83       895
#    macro avg       0.63      0.74      0.65       895
# weighted avg       0.90      0.83      0.86       895
#
#
# 🧮 Matriz de Confusión:
# [[ 50  30]
#  [121 694]]

# %% [markdown]
# ### Variacion undersampling esemble.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ======================
# 1. Cargar y preparar datos
# ======================
df = pd.read_excel("../Datos/DB_Comentarios_Clean.xlsx")
df = df.dropna(subset=["comentario", "calificacion"])

# Mapeo binario
rating_to_label = {1: "negativo", 2: "negativo", 3: "negativo", 4: "positivo", 5: "positivo"}
label_to_int = {"negativo": 0, "positivo": 1}
int_to_label = {0: "negativo", 1: "positivo"}
df["sentimiento"] = df["calificacion"].map(rating_to_label)
df["sentimiento_id"] = df["sentimiento"].map(label_to_int)

# División general train/test
X_train_texts, X_test_texts, y_train, y_test = train_test_split(
    df["comentario"], df["sentimiento_id"], test_size=0.2, stratify=df["sentimiento_id"], random_state=42
)

# ======================
# 2. Tokenización
# ======================
MAX_NUM_WORDS = 10000
MAX_SEQUENCE_LENGTH = 50
EMBEDDING_DIM = 100
NUM_EPOCHS = 10

tokenizer = Tokenizer(num_words=MAX_NUM_WORDS, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train_texts)

# Convertir texto a secuencias
X_train_seq = tokenizer.texts_to_sequences(X_train_texts)
X_test_seq = tokenizer.texts_to_sequences(X_test_texts)

X_train_pad = pad_sequences(X_train_seq, maxlen=MAX_SEQUENCE_LENGTH, padding="post", truncating="post")
X_test_pad = pad_sequences(X_test_seq, maxlen=MAX_SEQUENCE_LENGTH, padding="post", truncating="post")

# ======================
# 3. Definir función de modelo base
# ======================
def build_model():
    model = Sequential([
        Embedding(input_dim=MAX_NUM_WORDS, output_dim=EMBEDDING_DIM, input_length=MAX_SEQUENCE_LENGTH),
        Conv1D(filters=64, kernel_size=5, activation='relu'),
        GlobalMaxPooling1D(),
        Dropout(0.5),
        Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# ======================
# 4. Ensemble con undersampling balanceado
# ======================
df_neg = df[df["sentimiento_id"] == 0]
df_pos = df[df["sentimiento_id"] == 1]

N = 100
modelos = []

for i in range(N):
    df_pos_sample = resample(df_pos, replace=False, n_samples=len(df_neg), random_state=42 + i)
    df_bal = pd.concat([df_pos_sample, df_neg]).sample(frac=1, random_state=42 + i)

    X_bal_seq = tokenizer.texts_to_sequences(df_bal["comentario"])
    X_bal_pad = pad_sequences(X_bal_seq, maxlen=MAX_SEQUENCE_LENGTH, padding="post", truncating="post")
    y_bal = df_bal["sentimiento_id"].values

    model_i = build_model()
    model_i.fit(X_bal_pad, y_bal, epochs=NUM_EPOCHS, batch_size=32, verbose=0)
    modelos.append(model_i)

print(f"\nEntrenamiento finalizado: {N} modelos entrenados")
# Out:
# ✅ Entrenamiento finalizado: 100 modelos entrenados

# %%
# ======================
# 5. Predicción por votación
# ======================
preds = np.array([model.predict(X_test_pad, verbose=0).flatten() for model in modelos])
promedio_preds = np.mean(preds, axis=0)
y_pred_binario = (promedio_preds > 0.5).astype(int)

# ======================
# 6. Evaluación
# ======================
print(f"\nAccuracy: {accuracy_score(y_test, y_pred_binario):.4f}")
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred_binario, target_names=["Negativo", "Positivo"], digits=2))

print("\nMatriz de Confusión:")
conf_matrix = confusion_matrix(y_test, y_pred_binario)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=["Negativo", "Positivo"],
            yticklabels=["Negativo", "Positivo"])
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.title("Matriz de Confusión - Ensemble CNN")
plt.show()
# Out:
# 📊 Accuracy: 0.8506
#
# 📋 Reporte de clasificación:
#               precision    recall  f1-score   support
#
#     Negativo       0.36      1.00      0.53        81
#     Positivo       1.00      0.84      0.91       863
#
#     accuracy                           0.85       944
#    macro avg       0.68      0.92      0.72       944
# weighted avg       0.95      0.85      0.88       944
#
#
# 🧩 Matriz de Confusión:
