# %%
# Librerias necesarias para la extraccion de datos
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ## Fase 1. Extraccion de productos y url de productos a partir del manejo de la paginacion.

# %%
# Test extraccion listado de Urls productos, url de preguntas y respuestas a partir de la url de producto (Expreciones regulares)

# Lista de URLs que vamos a scrapear. (manejo de paginación)

urls = ['https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_49_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_97_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_145_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_193_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_241_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_289_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_337_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_385_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_433_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_481_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_529_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_577_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_625_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_673_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_721_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_769_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_817_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_865_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_913_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_961_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1009_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1057_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1105_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1153_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1201_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1249_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1297_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1345_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1393_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1441_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1489_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1537_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1585_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1633_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1681_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1729_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1777_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1825_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1873_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1921_NoIndex_True',
        #'https://listado.mercadolibre.com.co/ropa-accesorios/calzado/babuchas-pantuflas/nuevo/calzado_Desde_1969_NoIndex_True',
]

# Define headers, para simulación de un navegador y evitar bloqueos.
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Lista vacía donde vamos a guardar los datos.
data = []

# Ciclo para recorrer las URLs
for i, url in enumerate(urls, 1):
    print(f"Processing {i} of {len(urls)}")

    try:
        # Enviar una solicitud HTTP para obtener el contenido de la página.
        response = requests.get(url, headers=headers)

        # Si la respuesta no es exitosa, imprimir mensaje y continuar con la siguiente URL
        if response.status_code != 200:
            print(f"Error {response.status_code} en {url}. Saltando...")
            continue  # Pasa a la siguiente URL sin detener la ejecución
        
        # Parsear el contenido HTML de la página usando BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extraer los contenedores de los productos.
        productos = soup.find_all('li', {'class': 'ui-search-layout__item'})

        # Ciclo para recorrer cada producto y extraer la información.
        for producto in productos:
            try:
                # Extraer el nombre del producto.
                descripcion = producto.find('a', {'class': 'poly-component__title'}).text.strip()

                # Extraer URL del producto.
                url_producto = producto.find('a', href=True)['href']

                # Agregar la información a la lista de datos.
                data.append({
                    'descripcion': descripcion,
                    'url_producto': url_producto,
                })
            except AttributeError:
                print("Error al extraer datos del producto. Saltando...")  # Mensaje de error, pero sigue con los demás productos
                continue

    except requests.exceptions.RequestException as e:
        print(f"Error en la solicitud HTTP: {e}. Saltando...")  # Captura errores de conexión, tiempo de espera, etc.
        continue  # Sigue con la siguiente URL
# Out:
# Processing 1 of 1

# %%
data
# Out:
# [{'descripcion': 'Babuchas Y Pantuflas Hermosas Para Toda La Familia',
#   'url_producto': 'https://click1.mercadolibre.com.co/mclics/clicks/external/MCO/count?a=KVWSng%2BkEgI%2FrfX0qRcuEXc7H3h5pQe8XPFYK%2F8OAzL3S0LIZRPC0hqaatyR9HwUCjoQOLZ%2FubwAd69bKCbg6Zyi2%2FsP46uRg1wEmhNk3BFLNKsFuFNBOfD7gN7hRQMYODz05jM8yAEjSAY5w8aOVsuJp6C8XXFpfcCCHkZxBc0BwL3tnvhDgK94J76QUF2lq5cfiq9wsrFdLAH09SaiFoamTdekeMkY2vqpBAxD%2FxTIv4Q7MmeW6cDKXZHQC7a%2Fkc5uDec0PYIxJp0yVKAEdEYSYlzAcgsL9l%2F6cOTeJC%2BP3GXkDIWHMec8rZnVCi5B7FaeDOlzxDEVWAHeAWp3HyaAB6BFRQsSZvqxsC%2BX61nDHzI1YYe8KacdmSUX1a4nQciJw8dm5mJnKCtcXR3xeWP%2F%2BgjHQ%2BTZZY99FMWXLv1kbyIC89pPxIG3R2l1NwLVxHJundezjL
search_layout=grid&type=item&tracking_id=6d6178b4-678c-4da2-b13d-10f7660d8a1f'},
#  {'descripcion': 'Babuchas Y Pantuflas Hermosas Para Toda La Familia Capibara',
#   'url_producto': 'https://articulo.mercadolibre.com.co/MCO-2403562780-babuchas-y-pantuflas-hermosas-para-toda-la-familia-capibara-_JM?searchVariation=180565282608#polycard_client=search-nordic&searchVariation=180565282608&position=50&search_layout=grid&type=item&tracking_id=6d6178b4-678c-4da2-b13d-10f7660d8a1f'}]

# %%
# Convertir en un DataFrame
df = pd.DataFrame(data)
df.head()
# Out:
#                                          descripcion  \
# 0  Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 1  Pantuflas Mujer Hombre Niño Weps Termicas Anti...
# 2  Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 3  Pantufla Babucha Térmica Para Caballero Algodó...
# 4  Babuchas Pantuflas Termica, Antideslizante Unisex
#
#                                         url_producto
# 0  https://click1.mercadolibre.com.co/mclics/clic...
# 1  https://click1.mercadolibre.com.co/mclics/clic...
# 2  https://articulo.mercadolibre.com.co/MCO-58236...
# 3  https://articulo.mercadolibre.com.co/MCO-60118...
# 4  https://articulo.mercadolibre.com.co/MCO-19204...

# %%
# Exportar a Excel en caso de revisión.
# Se decambiar ruta y nombre del archivo.
#df.to_excel('../Datos/productos_urls_test.xlsx', index=False)

# %% [markdown]
# ### Construir el identificador de id de producto y pagina de preguntas y respuestas a partir de expresiones regulares.

# %%
# Codigo para extraer id de producto a partir de la url y crear la url de preguntas y respuestas.
import re

# Definir una función para extraer el ID del producto a partir de la URL
def extraer_id(url):
    match = re.search(r"MCO-\d+", url)
    return match.group(0).replace("-", "") if match else None

# Aplicar la función a la columna 'url_producto' para extraer el ID del producto
df['id_producto'] = df['url_producto'].apply(extraer_id)

# Crear la URL de preguntas y respuestas correctamente usando apply()
df['url_preguntas'] = df['id_producto'].apply(lambda x: f"https://articulo.mercadolibre.com.co/noindex/questions/{x}?scroll_to_question=2&new_version=true&modal=false" if x else None)

df.head()
# Out:
#                                          descripcion  \
# 0  Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 1  Pantuflas Mujer Hombre Niño Weps Termicas Anti...
# 2  Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 3  Pantufla Babucha Térmica Para Caballero Algodó...
# 4  Babuchas Pantuflas Termica, Antideslizante Unisex
#
#                                         url_producto    id_producto  \
# 0  https://click1.mercadolibre.com.co/mclics/clic...           None
# 1  https://click1.mercadolibre.com.co/mclics/clic...           None
# 2  https://articulo.mercadolibre.com.co/MCO-58236...   MCO582360754
# 3  https://articulo.mercadolibre.com.co/MCO-60118...   MCO601180326
# 4  https://articulo.mercadolibre.com.co/MCO-19204...  MCO1920460324
#
#                                        url_preguntas
# 0                                               None
# 1                                               None
# 2  https://articulo.mercadolibre.com.co/noindex/q...
# 3  https://articulo.mercadolibre.com.co/noindex/q...
# 4  https://articulo.mercadolibre.com.co/noindex/q...

# %%
df
# Out:
#                                           descripcion  \
# 0   Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 1   Pantuflas Mujer Hombre Niño Weps Termicas Anti...
# 2   Babuchas Y Pantuflas Hermosas Para Toda La Fam...
#
# Importar datos de el archivo de excel en caso de que queramos partir desde la revisioón de los datos.
# Se decambiar ruta y nombre del archivo.
#df = pd.read_excel('../Datos/productos_Copia.xlsx')
#df.head(20)

# %%
''''
Con el codigo a continuación se extrae las caracteristicas necesarias de cada producto 
- (descripcion, precio, calificaciones, valoraciones, vendedor, comentarios)'
- esto se agrega a un diccionario y se guarda en una lista que se llama data_productos.
'''

# %%
import requests
from bs4 import BeautifulSoup
import time

# Headers para simular un navegador y evitar bloqueos
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Lista vacía para almacenar los datos extraídos
data_productos = []

# Recorrer las URLs del DataFrame
for i, url in enumerate(df['url_producto'], 1):
    print(f"Processing {i} of {len(df['url_producto'])}")
    response = requests.get(url, headers=headers)
    
    if response.status_code != 200:
        print(f"Skipping URL {url} due to status code {response.status_code}")
        continue  # Saltar la iteración si la respuesta no es exitosa
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extraer el nombre del producto
    descripcion_elem = soup.find('h1', {'class': 'ui-pdp-title'})
    descripcion = descripcion_elem.text.strip() if descripcion_elem else "No disponible"
    
    # Extraer el precio del producto
    precio_elem = soup.find('span', {'class': 'andes-money-amount__fraction'})
    precio = precio_elem.text.strip() if precio_elem else "No disponible"
    
    # Extraer la calificación completa del producto
    calificacion_elem = soup.find('p', {'class': 'andes-visually-hidden'})
    calificacion_completa = calificacion_elem.text.strip() if calificacion_elem else "No disponible"
    
    # Extraer la cantidad de calificaciones del producto
    calificaciones_elem = soup.find('p', {'class': 'ui-review-capability__rating__label'})
    calificaciones = calificaciones_elem.text.strip() if calificaciones_elem else "No disponible"
    
    # Extraer la valoración del producto
    valoracion_elem = soup.find('p', {'class': 'ui-review-capability__rating__average ui-review-capability__rating__average--desktop'})
    valoracion = valoracion_elem.text.strip() if valoracion_elem else "No disponible"

    # Extraer calificación desde opiniones del superior
    calificacion_superior_elem = soup.find('span', {'class': 'ui-pdp-review__rating'})
    calificacion_superior = calificacion_superior_elem.text.strip() if calificacion_superior_elem else "No disponible"

    # Extraer cantidad de calificaciones del superior
    calificaciones_superior_elem = soup.find('span', {'class': 'ui-pdp-review__amount'})
    calificaciones_superior = calificaciones_superior_elem.text.strip() if calificaciones_superior_elem else "No disponible"

    # Extraer nombre del vendedor del superior
    vendor_superior_elem = soup.find('span', {'class': 'ui-pdp-seller__label-sold'})
    if vendor_superior_elem:
        vendedor_nombre_elem = vendor_superior_elem.find_next('span')  # Buscar el siguiente <span>
        vendor_superior = vendedor_nombre_elem.text.strip() if vendedor_nombre_elem else "No disponible"
    else:
        vendor_superior = "No disponible"

    # Extraer nombre del vendedor del inferior
    vendor_inferior_elem = soup.find('span', {'class': 'ui-pdp-color--BLACK ui-pdp-size--LARGE ui-pdp-family--REGULAR ui-seller-data-header__title non-selectable'})
    vendor_inferior = vendor_inferior_elem.text.strip() if vendor_inferior_elem else "No disponible"

    # Extraer cantidad de comentarios del producto.
    comentario_cantidad_elem = soup.find('span', {'class': 'ui-pdp-review__amount'})
    comentario_cantidad = comentario_cantidad_elem.text.strip() if comentario_cantidad_elem else "No disponible"

    # Extraer todos los comentarios disponibles.
    comentarios_elem = soup.find_all('p', {'class': 'ui-review-capability-comments__comment__content ui-review-capability-comments__comment__content'})
    comentarios = [comentario.text.strip() for comentario in comentarios_elem] if comentarios_elem else ["No disponible"]
    
    # Agregar la información a la lista
    data_productos.append({
        'descripcion': descripcion,
        'precio': precio,
        'calificacion_completa': calificacion_completa,
        'calificaciones': calificaciones,
        'valoracion': valoracion,
        'calificacion_superior': calificacion_superior,
        'calificaciones_superior': calificaciones_superior,
        'vendor_superior': vendor_superior,
        'vendor_inferior': vendor_inferior,
        'comentario_cantidad': comentario_cantidad,
        'comentarios': comentarios
    })

    # Pausa para evitar bloqueos
    time.sleep(3)

print("Scraping completado.")
# Out:
# Processing 1 of 50
# Processing 2 of 50
# Processing 3 of 50
# Processing 4 of 50
# Processing 5 of 50
# Processing 6 of 50
# Processing 7 of 50
# Processing 8 of 50
# Processing 9 of 50
# Processing 10 of 50
# Processing 11 of 50
# Processing 12 of 50
# Processing 13 of 50
# Processing 14 of 50
# Processing 15 of 50
# Processing 16 of 50
# Processing 17 of 50
# Processing 18 of 50
# Processing 19 of 50
# Processing 20 of 50
# Processing 21 of 50
# Processing 22 of 50
# Processing 23 of 50
# Processing 24 of 50
# Processing 25 of 50
# Processing 26 of 50
# Processing 27 of 50
# Processing 28 of 50
# Processing 29 of 50
# Processing 30 of 50
# Processing 31 of 50
# Processing 32 of 50
# Processing 33 of 50
# Processing 34 of 50
# Processing 35 of 50
# Processing 36 of 50
# Processing 37 of 50
# Processing 38 of 50
# Processing 39 of 50
# Processing 40 of 50
# Processing 41 of 50
# Processing 42 of 50
# Processing 43 of 50
# Processing 44 of 50
# Processing 45 of 50
# Processing 46 of 50
# Processing 47 of 50
# Processing 48 of 50
# Processing 49 of 50
# Processing 50 of 50
# Scraping completado.

# %%
# Añadir la informacion a un DataFrame
df_productos = pd.DataFrame(data_productos)

# Concatenar el DataFrame original con el nuevo
df = pd.concat([df, df_productos], axis=1)

df.head(20)
# Out:
#                                           descripcion  \
# 0   Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 1   Pantuflas Mujer Hombre Niño Weps Termicas Anti...
# 2   Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 3   Pantufla Babucha Térmica Para Caballero Algodó...
# 4   Babuchas Pantuflas Termica, Antideslizante Unisex
# 5   Pantuflas Babuchas Para Dama De Alta Calidad D...
# 6   Pantuflas Mujer Hombre Niño Weps Termicas Anti...
# 7   Pantuflas Babuchas Para Dama De Alta Calidad D...
# 8             Garras Colores Adulto Negra, Cafe, Gris
# 9   Pantufla Pantuflas Plataforma Suave Antidesliz...
# 10                       Pantuflas Bordadas De Snoopy
# 11                              Pantufla Fc Barcelona
# 12         Babuchas Pantuflas Pikachu Niños Y Adultos
# 13  Pantuflas Termicas Tipo Felpa Antideslizantes ...
# 14               Pantufla Babucha Materna Dama Sateen
# 15  Babuchas Pantuflas Cerdito Marranito Niñas Y A...
# 16                     Pantuflas Bordadas De Garfield
# 17  Pantuflas Pochita Babuchas Slippers Anime Chai...
# 18  Pantuflas Babuchas De Mujer Clasica Termica An...
# 6   Pantuflas Mujer Hombre Niño Weps Termicas Anti...  59.990
# 7   Pantuflas Babuchas Para Dama De Alta Calidad D...  54.000
# 8             Garras Colores Adulto Negra, Cafe, Gris  36.900
# 9   Pantufla Pantuflas Plataforma Suave Antidesliz...  45.000
# 10                       Pantuflas Bordadas De Snoopy  34.000
# 11                              Pantufla Fc Barcelona  42.900
# 12         Babuchas Pantuflas Pikachu Niños Y Adultos  39.900
# 13  Pantuflas Termicas Tipo Felpa Antideslizantes ...  89.990
# 14               Pantufla Babucha Materna Dama Sateen  46.500
# 15  Babuchas Pantuflas Cerdito Marranito Niñas Y A...  39.900
# 16                     Pantuflas Bordadas De Garfield  34.000
# 17  Pantuflas Pochita Babuchas Slippers Anime Chai...  49.900
# 18  Pantuflas Babuchas De Mujer Clasica Termica An...  55.000
# 19  Pantuflas Suela Gruesa Antideslizante Diseño V...  52.900
#
#                     calificacion_completa      calificaciones valoracion  \
# 0   Calificación 4.8 de 5. 282 opiniones.  282 calificaciones        4.8
# 1    Calificación 4.4 de 5. 26 opiniones.   26 calificaciones        4.4
# 2   Calificación 4.8 de 5. 282 opiniones.  282 calificaciones        4.8
# 3   Calificación 4.7 de 5. 200 opiniones.  200 calificaciones        4.7
# 4    Calificación 4.5 de 5. 78 opiniones.   78 calificaciones        4.5
# 5    Calificación 4.6 de 5. 83 opiniones.   83 calificaciones        4.6
# 6    Calificación 4.4 de 5. 26 opiniones.   26 calificaciones        4.4
# 7   Calificación 4.6 de 5. 288 opiniones.  288 calificaciones        4.6
# 8   Calificación 4.8 de 5. 288 opiniones.  288 calificaciones        4.8
# 9    Calificación 4.8 de 5. 21 opiniones.   21 calificaciones        4.8
# 10  Calificación 4.8 de 5. 152 opiniones.  152 calificaciones        4.8
# 11   Calificación 4.8 de 5. 17 opiniones.   17 calificaciones        4.8
# 12   Calificación 4.4 de 5. 13 opiniones.   13 calificaciones        4.4
# 13   Calificación 4.2 de 5. 29 opiniones.   29 calificaciones        4.2
# 14   Calificación 4.8 de 5. 48 opiniones.   48 calificaciones        4.8
# 15   Calificación 4.8 de 5. 31 opiniones.   31 calificaciones        4.8
# 16   Calificación 4.9 de 5. 54 opiniones.   54 calificaciones        4.9
# 17   Calificación 4.6 de 5. 68 opiniones.   68 calificaciones        4.6
# 18   Calificación 4.1 de 5. 15 opiniones.   15 calificaciones        4.1
# 19   Calificación 4.8 de 5. 18 opiniones.   18 calificaciones        4.8
#
#    calificacion_superior calificaciones_superior        vendor_superior  \
# 0                    4.8                   (282)               ROCHY 27
# 1                    4.4                    (26)             BUILDER CO
# 2                    4.8                   (282)               ROCHY 27
# 3                    4.7                   (200)        AMARE_PANTUFLAS
# 4                    4.5                    (78)  MULTIPLACECOLOMBIACOM
# 5                    4.6                    (83)  MULTIPLACECOLOMBIACOM
# 6                    4.4                    (26)             BUILDER CO
# 7                    4.6                   (288)  MULTIPLACECOLOMBIACOM
# 8                    4.8                   (288)                1JENNY8
# 9                    4.8                    (21)            MOOS4026166
# 10                   4.8                   (152)           XAERTZ STORE
# 11                   4.8                    (17)        CREACIONES MAYI
# 12                   4.4                    (13)          TIENDA SHEKEL
# 13                   4.2                    (29)             BUILDER CO
# 14                   4.8                    (48)        AMARE_PANTUFLAS
# 15                   4.8                    (31)          TIENDA SHEKEL
# 16                   4.9                    (54)           XAERTZ STORE
# 17                   4.6                    (68)             BOGOTOWN97
# 18                   4.1                    (15)  MULTIPLACECOLOMBIACOM
# 19                   4.8                    (18)  MULTIPLACECOLOMBIACOM
#
#                 vendor_inferior comentario_cantidad  \
# 0          Vendido por ROCHY 27               (282)
# 1                 No disponible                (26)
# 2          Vendido por ROCHY 27               (282)
# 3   Vendido por AMARE_PANTUFLAS               (200)
# 4                 No disponible                (78)
# 5                 No disponible                (83)
# 6                 No disponible                (26)
# 7                 No disponible               (288)
# 8           Vendido por 1JENNY8               (288)
# 9       Vendido por MOOS4026166                (21)
# 10     Vendido por XAERTZ STORE               (152)
# 11  Vendido por CREACIONES MAYI                (17)
# 12                No disponible                (13)
# 13                No disponible                (29)
# 14  Vendido por AMARE_PANTUFLAS                (48)
# 15                No disponible                (31)
# 16     Vendido por XAERTZ STORE                (54)
# 17       Vendido por BOGOTOWN97                (68)
# 18                No disponible                (15)
# 19                No disponible                (18)
#
#                                           comentarios
# 0   [100% recomendadas. Excelentes para descansar ...
# 1   [Respondió a mis expectativas., Preciosas exce...
# 2   [100% recomendadas. Excelentes para descansar ...
# 3   [Muy bien producto, me ayudó mucho la especifi...
# 4   [Muy buen producto., Me iba quedando un poco p...
# 5   [Muy cómodas me gustaron muchob., Hermosas y c...
# 6   [Respondió a mis expectativas., Preciosas exce...
# 7   [Muy linda y bellas mis babuchas de gatito!., ...
# 8   [Entre gustos y colores me facinaron calentito...
# 9   [Son realmente muy cómodas. Los materiales qui...
# 10  [, Super bonito., , Justo lo que esperaba., Di...
# 11  [Eran para un regalo.\nMuy cómodas.\nAl estamp...
# 12  [Lindas pero no tan bien cocidas., , Excelente...
# 13  [Es bueno, pero debe informarse mejor sobre el...
# 14  [Excelente, muy suaves y cómodas., Muy bueno. ...
# 15  [Me encabto., Son hermosaa y suaves!., Hermosa...
# 16  [Buen producto., Muy lindas, de buena calidad ...
# 17  [Son justo lo que esperaba, a mi novia le enca...
# 18  [Me encantaron. Son cómodas y se ven muy hermo...
# 19  [Gracias, a mi amiga lesbi le encantaron 200 d...

# %%
# Exportar el DataFrame a un excel
# Se decambiar ruta y nombre del archivo.
#df.to_excel('../Datos/productos_con_datos_25feb.xlsx', index=False)

# %% [markdown]
# ## Fase 3. Extraccion de preguntas y respuestas.

# %%
# Crear una lista vacía para almacenar las preguntas y respuestas
data_preguntas = []

# Definir headers para evitar bloqueos en las solicitudes
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Recorrer las URLs de preguntas y respuestas
for i, url in enumerate(df['url_preguntas'], 1):
    print(f"Processing {i} of {len(df['url_preguntas'])}")
    
    # Verificar si la URL es válida
    if not isinstance(url, str) or not url.startswith("http"):
        print(f"Skipping invalid URL: {url}")
        data_preguntas.append({'preguntas': [], 'respuestas': []})  # Agregar lista vacía para mantener el orden
        continue  # Saltar esta iteración si la URL no es válida

    # Enviar una solicitud HTTP para obtener el contenido de la página con headers
    response = requests.get(url, headers=headers)
    
    if response.status_code != 200:
        print(f"Skipping URL {url} due to status code {response.status_code}")
        data_preguntas.append({'preguntas': [], 'respuestas': []})  # Agregar lista vacía para mantener el orden
        continue  # Saltar esta iteración si la solicitud no fue exitosa
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extraer las preguntas
    preguntas = [p.text.strip() for p in soup.find_all('span', {'class': 'ui-pdp-color--BLACK ui-pdp-size--SMALL ui-pdp-family--REGULAR ui-pdp-questions__questions-list__question'})]
    
    # Extraer las respuestas
    respuestas = [r.text.strip() for r in soup.find_all('span', {'class': 'ui-pdp-color--GRAY ui-pdp-size--SMALL ui-pdp-family--REGULAR ui-pdp-questions__questions-list__answer-item__separate ui-pdp-questions__questions-list__answer-item__with-tapeables-links'})]

    # Agregar la información alineada con el DataFrame original
    data_preguntas.append({'preguntas': preguntas, 'respuestas': respuestas})

    # Pausa para evitar bloqueos
    time.sleep(2)

print("Scraping completado.")
# Out:
# Processing 1 of 50
# Skipping invalid URL: None
# Processing 2 of 50
# Skipping invalid URL: None
# Processing 3 of 50
# Processing 4 of 50
# Processing 5 of 50
# Processing 6 of 50
# Processing 7 of 50
# Processing 8 of 50
# Processing 9 of 50
# Processing 10 of 50
# Processing 11 of 50
# Processing 12 of 50
# Processing 13 of 50
# Processing 14 of 50
# Processing 15 of 50
# Skipping URL https://articulo.mercadolibre.com.co/noindex/questions/MCO647429575?scroll_to_question=2&new_version=true&modal=false due to status code 404
# Processing 16 of 50
# Processing 17 of 50
# Processing 18 of 50
# Processing 19 of 50
# Skipping URL https://articulo.mercadolibre.com.co/noindex/questions/MCO1257456082?scroll_to_question=2&new_version=true&modal=false due to status code 404
# Processing 20 of 50
# Processing 21 of 50
# Processing 22 of 50
# Processing 23 of 50
# Processing 24 of 50
# Processing 25 of 50
# Skipping URL https://articulo.mercadolibre.com.co/noindex/questions/MCO1794336040?scroll_to_question=2&new_version=true&modal=false due to status code 404
# Processing 26 of 50
# Processing 27 of 50
# Processing 28 of 50
# Processing 29 of 50
# Processing 30 of 50
# Processing 31 of 50
# Processing 32 of 50
# Processing 33 of 50
# Processing 34 of 50
# Processing 35 of 50
# Skipping URL https://articulo.mercadolibre.com.co/noindex/questions/MCO583437610?scroll_to_question=2&new_version=true&modal=false due to status code 404
# Processing 36 of 50
# Processing 37 of 50
# Processing 38 of 50
# Processing 39 of 50
# Processing 40 of 50
# Skipping URL https://articulo.mercadolibre.com.co/noindex/questions/MCO1441319099?scroll_to_question=2&new_version=true&modal=false due to status code 404
# Processing 41 of 50
# Skipping URL https://articulo.mercadolibre.com.co/noindex/questions/MCO1684067018?scroll_to_question=2&new_version=true&modal=false due to status code 404
# Processing 42 of 50
# Skipping URL https://articulo.mercadolibre.com.co/noindex/questions/MCO2233083152?scroll_to_question=2&new_version=true&modal=false due to status code 404
# Processing 43 of 50
# Processing 44 of 50
# Processing 45 of 50
# Processing 46 of 50
# Processing 47 of 50
# Processing 48 of 50
# Processing 49 of 50
# Processing 50 of 50
# Scraping completado.

# %%
data_preguntas
# Out:
# [{'preguntas': [], 'respuestas': []},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': ['Buenos días, ¿se pueden lavar en lavadora?',
#    'Yo cancelé una compra y me descontaron la plata. Cómo la recupero?',
#    'Buenas tardes, realicé la compra de unas babuchas, están muy bonitas y de excelente calidad, sólo que me quedaron pequeñas, Quiero saber cómo puedo cambiarlas por una talla más grande, Gracias',
#    'Muchas Gracias, ya realicé el pago de las babuchas azul oscuro con suela rosada',
#    'Buenos días, disculpa la última pregunta la suela es flexible o rígida?',
#    'Muchas Gracias por la información',
#    'Si aislan bien el frío?',
#    'Buenas tardes, las babuchas vienen con suelas antideslizantes?',
#    'buenas tardes, si te pido 2 pares. Talla 36 y 41. Cuando llegan?',
#    'Buenas noches, me gustaría pedir las pantuflas rojas con el motivo de Mafalda, pero en los diseños que muestras aparece con el nombre “Azul”, pero son rojas con negro. Cómo se deben pedir?',
#    'Buen día, me interesa pedir 6 pares. Pero me gustaria saber los motivos y formas',
#    'Direccion',
#    'Buenas tardes, estoy buscando unas pantuflas negras de la talla 44 a 45. O de superheroes en esas mismas tallas, tienes?',
#    'Si marco la opcion azul marino seguro me llegan las de gato?',
#    'Buenas tardes. Las de gato son negras? Las hay en otro color con la cara de de gato?',
#    'El calza 43 normalmente, pero como aquí dice que hay que pedir un número más...',
#    'Necesito para hombre unas de talón bajo, negras en talla 44... Es posible? Gracias',
#    'Buenas noches. En caso de que la talla no quede bien se puede hacer el cambio?'],
#   'respuestas': ['Buenos días recomendamos lavar a mano con detergentes suaves y cepillo de celdas suaves si las puede centrifugar en la lavadora.',
#    'Buen día. Cualquier problema que tengas con tu dinero puedes realizar una consulta en ayuda de mercado libre',
#    'Buenas noches ya te escribimos al interno para gestionar sobre tu consulta.',
#    'Buenas tardes perfecto si sra',
#    'Buenas tardes. Es Flexible',
#    'con gusto',
#    'Si sra son bien calientitas.',
#    'Buenas tardes si sra suela cosida de caucho antideslizante',
#    'Buenas tardes si se encuentra en bogota le llegarían el martes . Fuera de bogota el jueves',
#    'Buenas noches si sra se envía las q aparecen en la foto osea mafalda.',
#    'Buenas tardes si sra tenemos en la publicación 10 diseños',
#    'Buenos días por políticas de mercado libre no me permite compartirle la dirección exacta. Es bogota bosa.',
#    'Buenas tardes La talla más grande q tenemos es 43.',
#    'Si sra le llegan las de gato negro. el tallaje es normal igual al calzado q usa normalmente para dama . Para caballero si recomendamos una talla por encima de la q usa normalmente.',
#    'Si sra buenas tardes. son negra .',
#    'Si sra Podría depronto medirle el pie desde la punta del dedo gordo hasta el talón sin darle aumento y miramos si las medidas le serviría la talla 43',
#    'Buenos días Las manejamos hasta la talla 43.',
#    'Buenas noches si sr si esta en bogota seria el proceso un poco más rápido directamente con nosotros. Pero para caballero recomendamos una talla por encima de la q usa normalmente. Para dama el tallaje es normal igual al calzado q usa normalmente.']},
#  {'preguntas': ['Buenas tardes Requiero de su asesoría es para una persona que tiene muy inchados los pies, las actuales son US7-8'],
#   'respuestas': ['Buenas tardes en tallaje nacional normalmente que talla usa la persona? Le entiendo que el calzado us 7-8 que más o menos es un 40 nacional le queda bien en cuanto al ancho']},
#  {'preguntas': ['hola, te quedan color gris, talla 37? no me deja agregarlas, gracias',
#    'Hola, ustedes se encargan de mandarme las tallas correctas si yo elijo mi talla real ??',
#    'Buenas tardes, solo me aparece disponibles rosado y lila, tienes algún otro color disponible ?',
#    'Buenas noches, te pregunto calzo 37 entonces qué talla tengo que pedir?'],
#   'respuestas': ['Buenas tardes para persona que calce 37 la pantufla debe ser 38-39 y si esta disponible',
#    'Hola buenas tardes debe seleccionar la talla que calzas y nosotros te enviaremos la adecuada para tu talla',
#    'Hola solo disponibles en el momento en rosa claro, salmon y lila',
#    'Si calzas talla 37, debes elegir la talla 37 al momento de hacer la compra. Nosotros nos encargaremos de enviarte la talla indicada. ¡Quedo atento a tu compra!']},
#  {'preguntas': ['Hola, no tengo necesidad de escoger una talla mayor, ya que uds me enviaran una talla encima de la que yo escojo, ¿si?, si escojo 36-37, uds me enviaran la 38-39.',
#    'Buenas tardes, quisiera saber sí las pantuflas vienen en talla pequeña o normal?',
#    'Se puede ir a dónde está el producto y recogerlo.'],
#   'respuestas': ['Al momento de la compra, eliges la talla que habitualmente calzas, y nos encargamos de enviarte la talla adecuada de pantuflas. si escojes 36-37 te enviaremos 38-39',
#    'Buen dia al momento de la compra elijes la talla que habitualmente calzas y nos encargamos de enviarte la talla adecuada de pantuflas ya que el tallaje si es pequeño',
#    'Lo siento, pero no es posible recoger el producto en el lugar donde se encuentra. Para conocer las opciones de envío disponibles y los tiempos de llegada, puedes revisar la página del producto. ¡Estoy aquí para ayudarte con cualquier otra pregunta que tengas!']},
#  {'preguntas': ['Y en otro color si tienen talla mas pequeña, army green? 34-35?',
#    'Buenas noches, tienen en Talla 34-35 y color negro? Con base en tallas de la Guía, debería ser 34-35. Me confirman por favor si realizo la compra en 36 que es la mas pequeña que permite comprar y les confirmo vía mensaje. Gracias',
#    'Quiero una para mi esposa y otra para mi. Obviamente son tallas diferentes. Podría comprar cantidad dos y coordinar con ustedes el color y talla para cada uno.?',
#    'Hola, tienes descuento por una docena?',
#    'tienes la talla 44 de Colombia? Colores?',
#    'son forradas en tela de impermeable'],
#   'respuestas': ['¡Hola! Actualmente, no tenemos disponible la talla 34-35 en color army green. La talla más pequeña que puedes seleccionar es la 36. Si decides realizar la compra en esa talla, estaré aquí para ayudarte con cualquier consulta que tengas después. ¿Te gustaría saber más sobre las características de las pantuflas o sobre el proceso de compra?',
#    '¡Buenas noches! Actualmente, no tenemos disponible la talla 34-35 en color negro. La talla más pequeña que puedes seleccionar es la 36. Si decides realizar la compra en esa talla, estaré aquí para ayudarte con cualquier consulta que tengas después. ¿Te gustaría saber más sobre las características de las pantuflas o sobre el proceso de compra?',
#    '¡Claro! Puedes realizar la compra de dos pares y seleccionar las tallas y colores que desees para cada uno en el momento de la compra. Solo asegúrate de revisar la tabla de tallas que se encuentra en las imágenes de la publicación para elegir la correcta. Recuerda que el precio es el publicado y no se hacen descuentos por cantidad. Si tienes alguna otra pregunta o necesitas ayuda con el proceso de compra, no dudes en decírmelo. ¿Ya tienes en mente qué colores y tallas te gustaría elegir?',
#    'El precio es el publicado. Puedes ver el precio en la publicación. No se hacen descuentos por cantidad y los precios incluyen IVA. Si tienes alguna otra pregunta o necesitas más información sobre el producto, estaré encantado de ayudarte. ¿Te gustaría saber algo más específico sobre las pantuflas?',
#    'Lamentablemente, no contamos con la talla 44 en este momento. Las tallas disponibles son desde la 36 hasta la 43. En cuanto a los colores, tenemos opciones como negro, verde militar, rosado, azul y crema. ¿Te gustaría saber más sobre alguna de estas tallas o colores en particular?',
#    'Las pantuflas no están forradas en tela impermeable, pero cuentan con una capa exterior de poliéster que repele el agua, lo que las hace resistentes a la humedad. Sin embargo, no son completamente impermeables. Si tienes más preguntas sobre el producto o necesitas información adicional, no dudes en preguntar.']},
#  {'preguntas': ['Cayendo entregan en Bogotá',
#    'Hola. Tienen en 38 negras? es que no me salen disponible. Gracias!',
#    'Hola, no me deja seleccionar la talla 40 azul. Si hay disponible?',
#    'Hola dónde están ubicados? Es que necesito un regalo pero por aquí se me demora y es para un regalo, gracias'],
#   'respuestas': ['Hola, el tiempo de entrega estimado es de 3 a 5 días hábiles una vez realizada la compra, y hacemos envíos a diversas localidades, incluyendo Bogotá. ¡Estamos a tu disposición para cualquier otra pregunta que tengas y para ayudarte a realizar tu compra!',
#    'Hola, lamentablemente no tenemos disponibles zapatos en talla 38 y color negro. Sin embargo, tenemos varias opciones en talla 38 en otros colores, como azul y rosa. Si estás interesado en alguna de estas opciones, no dudes en preguntar. ¡Estamos aquí para ayudarte en tu compra!',
#    'Sí, la talla 40 azul está disponible. Actualmente hay 40 unidades en stock.',
#    'Hola buen día estamos en Bogotá']},
#  {'preguntas': ['Hola si pido hoy me puede llegar mañana?',
#    'Buen día me puedes regalar una tabla de guía de tallas por favor!',
#    'Pueden llegar antes de jueves??',
#    'Buenas noches. No le vuelven a llegar de sullivan?',
#    'Las necesito en 41-42',
#    'Buenas tardes Están disponibles?',
#    'La talla sería la que dice 33-34?',
#    'Hola! Me confirmas si las tienes en azul (Sullivan) en talla 34?',
#    'Hola necesito unas tallas 39 o 40 naranjas o amarillas'],
#   'respuestas': ['Beun dia, no es probable, te llegan el sabado si estas en Bigita',
#    'Buen dia bajo la foto de la publicación la puede encontrar',
#    'Buen dia, yo te enviaria mañana, depende de mercado libre entregarte',
#    'Buen dia, por este año agotadas:(',
#    'Claro que si, disponible en color negro, cafe, azul, y gris',
#    'Buen dia, si esta disponible',
#    'Correcto',
#    'Buen dia, si hay disponible',
#    'Buen dia, si señora, por encargo, realizas la compra y me indicas el color']},
#  {'preguntas': ['No tienen talla 43 para hombre?',
#    'Listo , amiga pago aprobado , serían negras talla 36 , cuando llegarían ?? Gracias',
#    'Ok amiga ya pagué , te recuerdo que son las negras talla 36',
#    'Tiene las negras en tall 36 ?',
#    'Hola tienes estas negras en talla 36 ?',
#    'Tiene tallas más grandes?',
#    'Cuanto se demora el envío a Bogota?',
#    'Cuanto se demora el envío a Bogota?',
#    'Que medida trae la talla 38',
#    'Buenas tardes me dice que mi pedido llegó pero no, quisiera saber qué psdo',
#    'hola, no hay talla 39?'],
#   'respuestas': ['No manejamos esa talla',
#    'Hola! Puedes verificar los métodos y tiempos de llegada en la página del producto. La fecha que te indico MCL',
#    'Allí puedes mirar la guía de tallas',
#    'Sí, el color negro está disponible en talla 35-36.',
#    'Hola si disponible.',
#    'Hola la talla mas grande que tenemos es la 38-39 de 24.5 cm',
#    'Hola! Puedes verificar los métodos y tiempos de llegada en la página del producto.',
#    'Hola, en la página del producto puedes verificar los métodos de envío disponibles y los tiempos de llegada.',
#    'Hola, 24 cm aproximadamente',
#    'Hola, desde la ciudad de Medellín. Si tu pedido aparece como entregado pero no lo has recibido, te recomendaría que te pongas en contacto con la empresa de mensajería que realizó la entrega para que te brinden más información sobre la entrega. Saludos.',
#    'Hola, mira la guía de tallas la 38 casi siempre sirve también para 39. Saludos']},
#  {'preguntas': ['Hola, buenas tardes, tienes algunas de Toy Story o Buzz Lightyear para adulto ?',
#    'Hola, están preciosas, me podrías confirmar cuál es el grueso de la suela y si transpasa el frío del suelo porfa, mil gracias.',
#    'Buenas noches para villavicencio cuanto demoraría el envío',
#    'Hola buenos días más o menos 28cm o más o menos? Es que el pie de él mide exactamente 28cm, le quedaría?',
#    'Tienes la medida en cm de la talla más grande 42-43?',
#    'Mi novio es talla 42-43 en zapatos, que talla debería pedirle?',
#    'Gracias , si encargo los dos pares de pantuflas para manizales caldas , me cobran un solo envío, gracias',
#    'Buenas tardes Busco un par de babuchas de snoopy y otro par de spaiderman, gracias',
#    'Buenos días, donde puedo ver los modelos disponibles?',
#    'Hola! Si fuese para un regalo, le pueden agregar una tarjeta o algo así? Gracias',
#    'Hola, en las fotos de opiniones se ve snoopy sin nariz. Podriamos asegurarnos que el par que compre tenga nariz?'],
#   'respuestas': ['Hola buen día, no no tenemos disponibles',
#    'Hola como estás, es de aproximadamente 2cm y no transpasa el frio',
#    'Buenas noches, masomenos 2 días',
#    'La pantufla mide exacto los 28 cm, lo mas probable es que le quede muy apenas',
#    'La suela mide maso menos 28 cm',
#    'Hola como estás, la talla más grande que manejamos es la 42-43',
#    'Debes agregar cada par al carrito y luego hacer la compra desde el carrito para que solo te cobren 1 envio',
#    'Hola como estás, de spiderman te ofrezco estas https://articulo.mercadolibre.com.co/MCO-604781777-pantuflas-bordadas-del-hombre-arana-_JM',
#    'Hola buen día, desde acá puedes ver nuestros diseños https://listado.mercadolibre.com.co/ropa-accesorios/_CustId_345085571_PrCategId_AD#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D3%26applied_value_id%3DMCO1430%26applied_value_name%3DRopa+y+Accesorios%26applied_value_order%3D10%26applied_value_results%3D62%26is_custom%3Dfalse',
#    'Hola buen dia, claro que si, tendrías que avisarnos por medio del chat de la compra',
#    'Hola buenas tardes, de momento las tenemos sin nariz']},
#  {'preguntas': ['Buenos días la suela no es de tela?',
#    'Hola. Las necesito para esta semana para Bogotá. Alcanzan a llegar?',
#    'Hola estoy en Bogota necesito unas talla39 40 de millonarios cuanto tardan en llagar ?',
#    'Hola buenos días se puede recoger en algun lado?',
#    'Muchas gracias! Ya hice la compra de los 3 pares. Te agradezco mucho que los envíes lo más pronto posible por favor. Gracias!',
#    'Si te compro tres pares en este momento, por favor me ayudas a que se despachen hoy mismo?',
#    'Disculpa, y no podemos nosotros recoger en algún lado para que sea más rápido por favor?',
#    'Hola, necesito unas pantuflas del Barca y otras del Real Madrid negras talla 34-35. Los tienes para entrega esta semana por favor? Podemos pasar a recogerlas sin problema'],
#   'respuestas': ['¡Hola! La suela de las pantuflas FC Barcelona es de suela sintética antideslizante, lo que garantiza una alta durabilidad y seguridad al caminar. Si estás interesado en adquirirlas, no dudes en hacérnoslo saber. ¡Estamos aquí para ayudarte!',
#    'Buenas tardes maximo le llega el martes',
#    'Hola El tiempo de entrega es de dos a tres días hábiles',
#    'Buenos días. Desde Rionegro Antioquia se envía, por lo que no es posible recoger el pedido en una tienda. Puedes verificar los métodos y tiempos de llegada en la página del producto. ¿Hay algo más en lo que pueda ayudarte con respecto a las pantuflas del Fc Barcelona?',
#    'Con mucho gusto. Gracias',
#    'Hoy mismo las despacho',
#    'Desde Rionegro antioquia se envía',
#    'Buenos días. si están disponibles pero no le puedo asegurar que lleguen está misma semana, ya que se envía desde la fabrica principal la cula no queda en Bogotá']},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': ['Hola tengo un inconveniente con el envio ya que , quisiera saber si se pueden comunicar conmigo para que me pueda llegar',
#    'Hola, busco para un pie que mida 25.5cms.',
#    'Estás de 47k y las de 51k son iguales?',
#    'Es decir son todas color castaño incluso la suela?',
#    'Amigo veo que tiene dos productos iguales pero fotos diferentes y precios diferentes, quisiera saber si las dos vienen con suela negra o color crema como la pantufla en general?'],
#   'respuestas': ['Entiendo tu preocupación con respecto al envío. Sin embargo, la plataforma es la que gestiona los envíos y no podemos comunicarnos directamente. Te recomiendo que ingreses tu dirección en la plataforma para verificar si hay opciones de despacho disponibles. Si no aparece ninguna opción, es posible que no se pueda realizar el envío a tu ubicación. Para revisar tu caso en detalle, te sugiero que contactes a través de la mensajería de Mercado Libre, donde el equipo encargado podrá ayudarte con tu requerimiento. ¿Hay algo más en lo que pueda asistirte?',
#    '¡Hola! Para un pie que mide 25.5 cm, te recomendaría considerar la talla 37-38, ya que esta tiene un largo de 25 cm. Sin embargo, como las pantuflas tienen una horma pequeña, es importante que verifiques si te sientes cómodo con esa medida. ¿Te gustaría saber más sobre las características de las pantuflas o sobre el proceso de compra?',
#    'No tengo esa información, pero puedo averiguarla. Te recomiendo que revises las características y detalles en la publicación para ver si hay alguna diferencia específica entre los dos productos. ¿Te gustaría saber algo más sobre las pantuflas?',
#    'La suela de las pantuflas es de color crema, mientras que el resto de la pantufla es de color castaño. Si tienes alguna otra pregunta o necesitas más información, no dudes en decírmelo.',
#    'Las pantuflas que mencionas tienen un diseño con suela de color crema. Si tienes alguna otra duda sobre las características o detalles de las pantuflas, no dudes en preguntar. ¿Te gustaría saber algo más específico sobre ellas?']},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': ['Buenos dias Quiero estar segura que llegan hoy sin las compro de inmediato Mil gracias'],
#   'respuestas': ['Buenos días. Si en la página le aparece “llega hoy” si le llega hoy']},
#  {'preguntas': ['Buenas noches. La suela es antideslizante',
#    'Hola, las tallas son las normales o vienen reducidas?',
#    'Hola necesito comprar una de niño y una de dama con un solo envio como puedo hacer?',
#    'Es decir q apenas te lleguen en 41 me puedes avisar por aquí? O habilitas la talla en éste espacio?',
#    'Puedo ir a verlas a punto de venta? Dónde? Recomiendo unas 41-42 para regalar en navidad.',
#    'Las naranjas en talla 41 tienen disponibles dónde se localizan?',
#    'La suela es antideslizante ?',
#    'Hola busco unas pantuflas cómodas. Pero tienen algunas sin muñecos? Yo soy talla 41 en zapatos pero a veces las chanclas vienen pequeñas. Desde el talón al dedo gordo mi pie mide 27.5 cms',
#    'Hola, me puedes facilitar la guía de tallas, por favor?',
#    'Hola! no tienes talle 30-31 para niña??'],
#   'respuestas': ['Hola buenas noches, si',
#    'Hola como estás, vienen reducidas, es aconsejable pedir la siguiente talla',
#    'Hola buen día Las debes agregar al carrito y ahí puedes generar la compra',
#    'Habilitamos la talla en la publicación',
#    'Por medio de preguntas de mercado libre no nos permiten pasar la dirección, sin embargo lucen tal cual la fotografia',
#    'Hola buen día, no las tenemos disponibles, nos llegan la otra semana, estamos en Bogotá',
#    'Buen día, si si es antideslizantw',
#    'Hola buen dia, te ofrezco estas, pidelas en talla 42-43 https://articulo.mercadolibre.com.co/MCO-604783469-pantuflas-cerradas-unicolor-adulto-_JM?attributes=COLOR_SECONDARY_COLOR:Um9zYQ==',
#    'Hola buen día, en la publicación en las tallas las puedes ver, sin embargo es aconsejable pedir la siguiebte talla, ya que el tallaje viene pequeño',
#    'Hola buenas tardes, de momento la talla más pequeña que tenemos es la 34, sin embargo el tallaje viene reducido']},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': ['Hola, buenas tardes, qué talla escojo para un niño de 3 años?',
#    'Buenas tardes necesito las babuchas y la pijama, para un niño de 3 años, me puedes hacer el link de pago por los dos productos? O con qué nombre los encuentro en la web..',
#    'Buenas noches tienen la pijama igual? Para un niño de 3 años'],
#   'respuestas': ['Buenas tardes la talla 24 26',
#    'Buenas tardes. Puede añadir cada producto al carrito de compras y así el envío le sale gratis',
#    'Buenos días. Si tenemos la Pijama en este link https://articulo.mercadolibre.com.co/MCO-592240921-pijamas-termicas-oso-escandaloso-ninos-ninas-_JM']},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': ['Buenos días, quisiera saber si me puedes colaborar para que llegue a Sogamoso Boyacá máximo el lunes en la mañana así toque pagar más',
#    'Hola buenos días tienen talla 39?'],
#   'respuestas': ['Hola, si podemos pero no por este canal, ya que el tema logístico del envío lo maneja directamente Mercadolibre',
#    'Buenos días, manejamos tallas pares, en este caso te recomendamos la talla 40']},
#  {'preguntas': ['Si usted me garantiza que me llega o el jueves o el viernes yo realizó la compra es que la necesito para el sábado o si no me da la dirección soy de Bogotá',
#    'Buenas tardes quiero saber si realizó el pedido de dos pantuflas me llagan mañana o por tardar el viernes o si se puede',
#    'Hola, ya realicé la compra de las pantuflas de bob esponja. Por donde te puedo escribir para cuadrar la talla',
#    'Son para niños o para adultos?'],
#   'respuestas': ['Hoy se las puedo enviar. Si me confirmas en este momento y si es probable que le llegue de mañana al sábado pero como dependemos de logística de una transportadora asegurar algo sería irresponsable. Esas pantuflas se envían desde la fabrica principal en Rionegro antioquia',
#    'Buenos días. Si te ubicas en ciudad principal le llega del jueves a lunes máximo',
#    'Ya te escribo',
#    'Hola. Puedes pedir cualquier talla pero por el interno me escribes para especificar la talla de niño q desea']},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': ['Buenas tardes como puedo pedir dos de diferente talla pero sin que aplique doble envío?',
#    'Ok pido 38 real, ya ustedes sabrán cual me mandan, gracias',
#    'Hola, la talla 38 es realmente 38 o vienen mas pequeñas oara saber porfa'],
#   'respuestas': ['Hola, para pedir dos productos de diferente talla sin que se aplique el costo de envío doble, puedes agregar ambos productos al carrito de compras y luego proceder con el pago. En el proceso de compra, el sistema calculará el costo de envío total para ambos productos. ¡Estamos a tu disposición para cualquier otra pregunta que tengas!',
#    'Correcto',
#    'Hola la talla 38 publicada es la real, pides 38 y enviamos 40-41 porque son reducidas. Pero pide tu talla normal']},
#  {'preguntas': ['Buenas noches tienes mocacin negro para hombre talla 40',
#    'Buenos días en CMS cuanto mide el número 39? Gracias'],
#   'respuestas': ['hola si tenemos',
#    'Hola, Yolima, la talla 39 tiene 25 cm, de medida,']},
#  {'preguntas': ['Buena noche q vale wnvio a medellin y hay talla 37 gracias',
#    'Buenas noches soy talla 37 que talla debo pedir?',
#    'tienen numero 40'],
#   'respuestas': ['El precio del envío a Medellín puede variar dependiendo del peso y tamaño del paquete, te recomendaría que ingreses tu dirección al momento de hacer la compra para que te indiquen el costo exacto. En cuanto a la disponibilidad de la talla 37, sí, actualmente contamos con existencias en esa talla. ¡Estoy a tu disposición para cualquier otra pregunta que tengas!',
#    'La talla adecuada para ti sería la talla 37.',
#    'Sí. el número 40 está disponible en este momento. Por favor realice la compra en talla 39 y por chat interno nos indica que es número 40. Saludos']},
#  {'preguntas': ['Buen día, me puedes orientar, estas son para un regalos, el calza 41, quiere decir que debo seleccionar la que dice 42-43? O la anterior que dice 40-41?',
#    'Buen día, soy 9 pero tengo el pie delgado que talla me queda bien',
#    'hola pero confirmas q me lleguen hoy, estoy en Bogota... no podría ser por transportadora',
#    'hola necesito 6 urgente me las podrias enviar hoy?',
#    'Hola necesito unas tallas 40 naranjas o amarillas'],
#   'respuestas': ['Buenas noches, es mejor la 42.43',
#    'Hola como estás las 40-41',
#    'Hola si, si compras ya ya que el mensajero aún no pasa',
#    'Hola buen día, si compras antes de la 1 si te las podemos enviar hoy mismo',
#    'Hola como estas, no manejamos en esos colores']},
#  {'preguntas': ['Hola, cuando tendrán talla 35-36 disponible en negro?',
#    'Buenos días. ¿Se pueden lavar en lavadora?',
#    'Hola, tienes talla 38 y talla 40 en negro?',
#    'Buenos días. Cuándo vuelven a tener disponible en talla 38-39? Ya sea verde o negro.',
#    'Necesito unas en 44 negras. Cuando le llegan?',
#    'Que pesar, es que mi esposo calza 42, sin embargo las 44 le quedaron pequeñas. Mil gracias en todo caso.',
#    'Buen día, quiero saber si tienen talla más grande de la 44, puede ser 45 o 46 en negro, mil gracias',
#    'Hola, buenas tardes, quisiera realz',
#    'Ya realicé la compra favor enviar talla 37 en color negro',
#    'Qué pena pero no entiendo primero me cuenta que no tiene 37 en color negro pero luego me responde que tiene 37 en color negro, si hay 37 en negro?!',
#    'En la talla 37 que color tiene??',
#    'Buenos días tiene talla 37 en color negro??',
#    'tienen disponile talla 35?',
#    'me gustaria el verde en talla 44 y el violeta en talla 38-39. Los tienes en inventario?',
#    'hola . Puedes enviar varios pares de diferente color y talla en la misma compra?'],
#   'respuestas': ['¡Hola! Actualmente no tengo información específica sobre la reposición de tallas, pero te recomiendo estar atento a la publicación, ya que se actualiza constantemente con el nuevo stock. También puedes considerar otras tallas o colores disponibles en este momento. ¿Te gustaría saber más sobre las características de las pantuflas o alguna otra consulta?',
#    '¡Buenos días! Sí, estas pantuflas son lavables a máquina. Puedes lavarlas en frío y secarlas al aire libre, lo que las hace muy prácticas y fáciles de mantener. ¿Te gustaría saber más sobre las tallas o colores disponibles?',
#    '¡Hola! Sí, tenemos disponible la talla 38 en negro. Sin embargo, la talla 40 no está disponible en este momento. Te recomiendo que revises la publicación para ver todas las opciones de tallas y colores disponibles. ¿Te gustaría saber algo más sobre las pantuflas?',
#    '¡Buenos días! Actualmente, no tengo información específica sobre la reposición de tallas, pero te recomiendo estar atento a la publicación, ya que se actualiza constantemente con el nuevo stock. También puedes revisar la tabla de tallas en las imágenes para asegurarte de elegir la correcta cuando estén disponibles. ¿Te gustaría saber más sobre las características de las pantuflas o alguna otra talla que te interese?',
#    '¡Hola! Las pantuflas en talla 44 y color negro están disponibles. El tiempo de entrega depende de tu ubicación, así que te recomiendo que ingreses tu dirección en la plataforma para verificar la fecha estimada de entrega. Recuerda que las compras realizadas antes de las 13hs se envían el mismo día, y después de esa hora se preparan para el envío al siguiente día hábil. ¿Te gustaría saber algo más sobre el producto o el proceso de compra?',
#    '¡Entiendo tu situación! Lamentablemente, las tallas disponibles para este modelo llegan hasta la 44, y no tenemos información sobre tallas más grandes en este momento. Te recomiendo estar atento a futuras actualizaciones de stock, ya que podríamos recibir nuevas tallas. Si necesitas ayuda con algo más o tienes alguna otra pregunta, ¡estaré encantado de asistirte! ¿Hay algún otro producto que estés considerando?',
#    '¡Buen día! Actualmente, las tallas disponibles para este modelo llegan hasta la 44. No tenemos información sobre tallas más grandes como la 45 o 46 en negro. Te recomiendo estar atento a futuras actualizaciones de stock, ya que podríamos recibir nuevas tallas. Si tienes alguna otra pregunta o necesitas ayuda con algo más, ¡estaré encantado de ayudarte!',
#    '¡Hola! Buenas tardes. Parece que tu mensaje se cortó. ¿Podrías darme más detalles sobre lo que necesitas? Estoy aquí para ayudarte con cualquier consulta que tengas.',
#    '¡Hola! Gracias por tu compra. Te confirmo que la talla 37 en color negro está disponible y será enviada según las condiciones de despacho. Recuerda que las compras realizadas antes de las 13hs se envían el mismo día, y las realizadas después se preparan para el envío al siguiente día hábil. Si tienes alguna otra pregunta o necesitas más información, no dudes en decírmelo. ¡Estoy aquí para ayudarte!',
#    '¡Hola! Lamento la confusión. Para aclarar, actualmente tenemos disponible la talla 37 en color negro. Te invito a revisar la publicación para confirmar la disponibilidad y ver todas las opciones que ofrecemos. Si tienes alguna otra pregunta o necesitas más información sobre algún otro color o talla, no dudes en decírmelo. ¡Estoy aquí para ayudarte!',
#    '¡Hola! En la talla 37, tenemos disponible el color negro y también el verde militar. Te invito a revisar la publicación para ver todas las opciones y detalles. ¿Te gustaría saber más sobre alguna de estas opciones?',
#    '¡Buenos días! Actualmente, no tenemos disponible la talla 37 en color negro. Sin embargo, contamos con otras tallas y colores, como el verde militar y morado. Te invito a revisar la publicación para ver todas las opciones disponibles. ¿Te gustaría saber más sobre alguna otra talla o color?',
#    '¡Hola! Sí, tenemos disponible la talla 35. Puedes revisar la disponibilidad y realizar tu compra directamente en la publicación. Si tienes alguna otra pregunta o necesitas ayuda con el proceso de compra, no dudes en decírmelo. ¿Te gustaría saber algo más sobre el producto?',
#    '¡Hola! Sí, tenemos disponible el color verde en talla 44 y el color violeta en talla 38-39. Puedes añadir ambos pares a tu carrito y proceder con la compra. ¿Te gustaría saber algo más sobre las características de las pantuflas o sobre el proceso de compra?',
#    '¡Hola! Sí, puedes seleccionar diferentes colores y tallas al momento de realizar tu compra. Solo asegúrate de añadir cada par que desees al carrito y elegir las variantes correspondientes. ¿Tienes en mente algún color o talla en particular que te gustaría combinar?']},
#  {'preguntas': ['Buen día Quisiera saber si la suela es muy gruesa y alta por favor.'],
#   'respuestas': ['Buenos días. No sra la suela como tal no es gruesa la espuma es de 2 cm de altura']},
#  {'preguntas': ['Buenas noches, qué talla sería para un niño de 3 años?'],
#   'respuestas': ['Buenas tardes. La talla 24-26']},
#  {'preguntas': ['Buen dia, como escoje uno la talla? Tienen disponible talla 39?'],
#   'respuestas': ['Ess una sola talla , el materia si tú tienes pequeño el pie no se preocupe nq no se va a salir ya q posee unas diminutas ventosas que sirven para fijar']},
#  {'preguntas': ['Buenas tardes. Si las mando hacer en talla 45 en cuanto tiempo las entregarían? Gracias',
#    'Buenos días. Me gusta sus pantuflas, pero las necesito en talla 45. Me podrias informar? Gracias'],
#   'respuestas': ['Dentro de la plataforma te calcula los tiempos de entrega, en producción están lista al día siguiente de la compra',
#    'Buen día si las podemos fabricar en talla 45, puede realizar la compra en otra talla y por chat interno nos indica que son talla 45']},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': ['Buenas... Podrían indicarme si pueden conseguir unas así en talla 41? Por favor...',
#    'Buenos días, te pregunto yo calzo 41 qué número debo de comprar el pie se me hincha un poco muchísimas gracias feliz tarde.'],
#   'respuestas': ['Lamentablemente, no tenemos disponibilidad de este producto en talla 41.',
#    'Hola, para la talla 41, lamentablemente no tenemos disponible esa talla en nuestras pantuflas. Las tallas que ofrecemos son 35-36, 37 y 38. Te sugerimos que revises la guía de tallas para encontrar la que mejor se ajuste a tus necesidades. Si tienes alguna otra pregunta o deseas realizar una compra, no dudes en decírnoslo. ¡Estamos aquí para ayudarte!']},
#  {'preguntas': ['Hola son para mujer o pueden ser unisex? Las necesito para hombre'],
#   'respuestas': ['Hola son horma de dama']},
#  {'preguntas': ['Hola, de casualidad no manejan de one piece?',
#    'Buenos días , llegaron las pantuflas ?',
#    'Buenas tardes, estoy pendiente de la llegada de las de harry poter, 1 36 y una 39 por favor',
#    'Y que otra opción tienes disponible en 35?',
#    'Buenas tardes realice la compra de pantuflas de harry poter y necesito 2 más iguales , una talla 39 y otra 35 , pero cuando voy a hacer la compra de la 35 no me da la opción ..',
#    'hola quiero pedirte tres pares para mujer , que mas diseños de disney tienes'],
#   'respuestas': ['Buenas noches, no lo manejamos',
#    'Hola buen día, recién llegaron, ahí te habilité la opción para realizar la compra',
#    'Hola como estás, aún no han llegado',
#    'Te ofrezco snoopy, garfiel, mafalda, los osos escandalosos',
#    'Hola como estás, porque no tenemos la talla disponible, nos llegan la otra semana',
#    'Hola, los diseños disponibles los puedes ver desde acá https://listado.mercadolibre.com.co/ropa-accesorios/calzado/_CustId_345085571_PrCategId_AD#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D4%26applied_value_id%3DMCO5208%26applied_value_name%3DCalzado%26applied_value_order%3D1%26applied_value_results%3D41%26is_custom%3Dfalse']},
#  {'preguntas': ['Hola, ¿la guia de tallas es correcta o esta desajustada? Porque indican que hay q pedir talla mas grande. Ella calza 37 normalmente. ¿Cual talla seria aca? Gracias :-)'],
#   'respuestas': ['Hola como estás, el tallaje viene muy reducido, yo también calzo 37 y uso la 40 para que me quede sueltita']},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': [], 'respuestas': []},
#  {'preguntas': ['Calzado 37, Cuál es la mas recomendable ?'],
#   'respuestas': ['Talla L']},
#  {'preguntas': ['Buenas tardes quiero hacer la compra pero quisiera que los datos de entrega sean a nombre de otra persona es posible eso?',
#    'Hola! Buenas noches. NO me llegaron las babuchas qué pedí (2 pares), llego un solo par de una referencia que no fue de las que elegí. Que puedo hacer para regresarla y que llegue mi pedido?',
#    'Hola buenas tardes, si te las compro ya me alcanzan a llegar para el sábado, discúlpame es que es para un cumpleaños ese día. Sería el envío a Villamaría Caldas, o así me toque pagar más por el envío'],
#   'respuestas': ['Buen dia, si , debes indicar al momento de ingrsae la dirección te piden el nombre de quien recibe',
#    'Hola puedes escribir por favor al chat de la compra para solucionar el inconveniente',
#    'Buen dia, debes revisar cuando dice mercado libre que te entrega,']},
#  {'preguntas': ['La suela si es resistente gruesa ?',
#    'Buen día yo soy talla 39 escojo 40 -41',
#    'Hola Disculpa que talla son?'],
#   'respuestas': ['Hola buen día, si, es en caucho',
#    'Hola buen dia, si es lo mejor para que no te queden apretadas',
#    'Hola como estás, en la publicación puedes elegir la talla']},
#  {'preguntas': ['Hola! Me interesa comprar unas color caqui talla 39 pero no me salen disponibles. ¿Cuándo las tienes disponibles nuevamente ?'],
#   'respuestas': ['Hola, no sabría decirte porque no nos ha vuelto a llegar el material para volver a hacerlas. Está agotado ese color']},
#  {'preguntas': ['???', 'Tiene talla 28 en rosado?'],
#   'respuestas': ['ESPERO TE HAYA QUEDADO CLARO',
#    'ESTE PRODUCTO VIENE DESDE LA TALLA 30, SON MEDIDAS REDUCIDAS QUE LE CORRESPONDE A UNA TALLA 29-30 REAL']},
#  {'preguntas': ['Porque no puedo pagar las sandalias ortopedicas por Efecty'],
#   'respuestas': ['Hola, en la página de detalles del producto tiene una tabla de tallas detallada, puedes medir el largo de tu pie, de acuerdo con la tabla de tallas para comprar la talla correcta, si tu empeine es más ancho o más gordo, ¡puedes comprar una talla más grande!']},
#  {'preguntas': ['De casualidad tienes un par pequeño en stock para entrega inmediata?'],
#   'respuestas': ['Buen día, lo que ves en la publicación es lo disponible.']}]

# %%
# Convertir a DataFrame para concatenar con el original
df_preguntas = pd.DataFrame(data_preguntas)

# Concatenar DataFrame original con preguntas y respuestas sin perder el índice original
df = pd.concat([df, df_preguntas], axis=1)

# Verificar la estructura final
df.head(20)
# Out:
#                                           descripcion  \
# 0   Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 1   Pantuflas Mujer Hombre Niño Weps Termicas Anti...
# 2   Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 3   Pantufla Babucha Térmica Para Caballero Algodó...
# 4   Babuchas Pantuflas Termica, Antideslizante Unisex
# 5   Pantuflas Babuchas Para Dama De Alta Calidad D...
# 6   Pantuflas Mujer Hombre Niño Weps Termicas Anti...
# 7   Pantuflas Babuchas Para Dama De Alta Calidad D...
# 8             Garras Colores Adulto Negra, Cafe, Gris
# 9   Pantufla Pantuflas Plataforma Suave Antidesliz...
# 10                       Pantuflas Bordadas De Snoopy
# 11                              Pantufla Fc Barcelona
# 12         Babuchas Pantuflas Pikachu Niños Y Adultos
# 13  Pantuflas Termicas Tipo Felpa Antideslizantes ...
# 14               Pantufla Babucha Materna Dama Sateen
# 15  Babuchas Pantuflas Cerdito Marranito Niñas Y A...
# 16                     Pantuflas Bordadas De Garfield
# 17  Pantuflas Pochita Babuchas Slippers Anime Chai...
# 18  Pantuflas Babuchas De Mujer Clasica Termica An...
# 19  Pantuflas Suela Gruesa Antideslizante Diseño V...
#
#                                          url_producto    id_producto  \
# 0   https://click1.mercadolibre.com.co/mclics/clic...           None
# 1   https://click1.mercadolibre.com.co/mclics/clic...           None
# 2   https://articulo.mercadolibre.com.co/MCO-58236...   MCO582360754
# 3   https://articulo.mercadolibre.com.co/MCO-60118...   MCO601180326
# 4   https://articulo.mercadolibre.com.co/MCO-19204...  MCO1920460324
# 5   https://articulo.mercadolibre.com.co/MCO-60068...   MCO600681077
# 6   https://articulo.mercadolibre.com.co/MCO-25526...  MCO2552653138
# 15  Babuchas Pantuflas Cerdito Marranito Niñas Y A...  39.900
# 16                     Pantuflas Bordadas De Garfield  34.000
# 17  Pantuflas Pochita Babuchas Slippers Anime Chai...  49.900
# 18  Pantuflas Babuchas De Mujer Clasica Termica An...  55.000
# 19  Pantuflas Suela Gruesa Antideslizante Diseño V...  52.900
#
#                     calificacion_completa      calificaciones valoracion  \
# 0   Calificación 4.8 de 5. 282 opiniones.  282 calificaciones        4.8
# 1    Calificación 4.4 de 5. 26 opiniones.   26 calificaciones        4.4
# 2   Calificación 4.8 de 5. 282 opiniones.  282 calificaciones        4.8
# 3   Calificación 4.7 de 5. 200 opiniones.  200 calificaciones        4.7
# 4    Calificación 4.5 de 5. 78 opiniones.   78 calificaciones        4.5
# 5    Calificación 4.6 de 5. 83 opiniones.   83 calificaciones        4.6
# 6    Calificación 4.4 de 5. 26 opiniones.   26 calificaciones        4.4
# 7   Calificación 4.6 de 5. 288 opiniones.  288 calificaciones        4.6
# 8   Calificación 4.8 de 5. 288 opiniones.  288 calificaciones        4.8
# 9    Calificación 4.8 de 5. 21 opiniones.   21 calificaciones        4.8
# 10  Calificación 4.8 de 5. 152 opiniones.  152 calificaciones        4.8
# 11   Calificación 4.8 de 5. 17 opiniones.   17 calificaciones        4.8
# 12   Calificación 4.4 de 5. 13 opiniones.   13 calificaciones        4.4
# 13   Calificación 4.2 de 5. 29 opiniones.   29 calificaciones        4.2
# 14   Calificación 4.8 de 5. 48 opiniones.   48 calificaciones        4.8
# 15   Calificación 4.8 de 5. 31 opiniones.   31 calificaciones        4.8
# 16   Calificación 4.9 de 5. 54 opiniones.   54 calificaciones        4.9
# 17   Calificación 4.6 de 5. 68 opiniones.   68 calificaciones        4.6
# 18   Calificación 4.1 de 5. 15 opiniones.   15 calificaciones        4.1
# 19   Calificación 4.8 de 5. 18 opiniones.   18 calificaciones        4.8
#
#    calificacion_superior calificaciones_superior        vendor_superior  \
# 0                    4.8                   (282)               ROCHY 27
# 1                    4.4                    (26)             BUILDER CO
# 2                    4.8                   (282)               ROCHY 27
# 3                    4.7                   (200)        AMARE_PANTUFLAS
# 4                    4.5                    (78)  MULTIPLACECOLOMBIACOM
# 5                    4.6                    (83)  MULTIPLACECOLOMBIACOM
# 6                    4.4                    (26)             BUILDER CO
# 7                    4.6                   (288)  MULTIPLACECOLOMBIACOM
# 8                    4.8                   (288)                1JENNY8
# 9                    4.8                    (21)            MOOS4026166
# 10                   4.8                   (152)           XAERTZ STORE
# 11                   4.8                    (17)        CREACIONES MAYI
# 12                   4.4                    (13)          TIENDA SHEKEL
# 13                   4.2                    (29)             BUILDER CO
# 14                   4.8                    (48)        AMARE_PANTUFLAS
# 15                   4.8                    (31)          TIENDA SHEKEL
# 16                   4.9                    (54)           XAERTZ STORE
# 17                   4.6                    (68)             BOGOTOWN97
# 18                   4.1                    (15)  MULTIPLACECOLOMBIACOM
# 19                   4.8                    (18)  MULTIPLACECOLOMBIACOM
#
#                 vendor_inferior comentario_cantidad  \
# 0          Vendido por ROCHY 27               (282)
# 1                 No disponible                (26)
# 2          Vendido por ROCHY 27               (282)
# 3   Vendido por AMARE_PANTUFLAS               (200)
# 4                 No disponible                (78)
# 5                 No disponible                (83)
# 6                 No disponible                (26)
# 7                 No disponible               (288)
# 8           Vendido por 1JENNY8               (288)
# 9       Vendido por MOOS4026166                (21)
# 10     Vendido por XAERTZ STORE               (152)
# 11  Vendido por CREACIONES MAYI                (17)
# 12                No disponible                (13)
# 13                No disponible                (29)
# 14  Vendido por AMARE_PANTUFLAS                (48)
# 15                No disponible                (31)
# 16     Vendido por XAERTZ STORE                (54)
# 17       Vendido por BOGOTOWN97                (68)
# 18                No disponible                (15)
# 19                No disponible                (18)
#
#                                           comentarios  \
# 0   [100% recomendadas. Excelentes para descansar ...
# 1   [Respondió a mis expectativas., Preciosas exce...
# 2   [100% recomendadas. Excelentes para descansar ...
# 3   [Muy bien producto, me ayudó mucho la especifi...
# 4   [Muy buen producto., Me iba quedando un poco p...
# 5   [Muy cómodas me gustaron muchob., Hermosas y c...
# 6   [Respondió a mis expectativas., Preciosas exce...
# 7   [Muy linda y bellas mis babuchas de gatito!., ...
# 8   [Entre gustos y colores me facinaron calentito...
# 9   [Son realmente muy cómodas. Los materiales qui...
# 10  [, Super bonito., , Justo lo que esperaba., Di...
# 11  [Eran para un regalo.\nMuy cómodas.\nAl estamp...
# 12  [Lindas pero no tan bien cocidas., , Excelente...
# 13  [Es bueno, pero debe informarse mejor sobre el...
# 14  [Excelente, muy suaves y cómodas., Muy bueno. ...
# 15  [Me encabto., Son hermosaa y suaves!., Hermosa...
# 16  [Buen producto., Muy lindas, de buena calidad ...
# 17  [Son justo lo que esperaba, a mi novia le enca...
# 18  [Me encantaron. Son cómodas y se ven muy hermo...
# 19  [Gracias, a mi amiga lesbi le encantaron 200 d...
#
#                                             preguntas  \
# 0                                                  []
# 1                                                  []
# 2   [Buenos días, ¿se pueden lavar en lavadora?, Y...
# 3   [Buenas tardes Requiero de su asesoría es para...
# 4   [hola, te quedan color gris, talla 37? no me d...
# 5   [Hola, no tengo necesidad de escoger una talla...
# 6   [Y en otro color si tienen talla mas pequeña, ...
# 7   [Cayendo entregan en Bogotá, Hola. Tienen en 3...
# 8   [Hola si pido hoy me puede llegar mañana?, Bue...
# 9   [No tienen talla 43 para hombre?, Listo , amig...
# 10  [Hola, buenas tardes, tienes algunas de Toy St...
# 11  [Buenos días la suela no es de tela?, Hola. La...
# 12                                                 []
# 13  [Hola tengo un inconveniente con el envio ya q...
# 14                                                 []
# 15  [Buenos dias Quiero estar segura que llegan ho...
# 16  [Buenas noches. La suela es antideslizante, Ho...
# 17                                                 []
# 18                                                 []
# 19                                                 []
#
#                                            respuestas
# 0                                                  []
# 1                                                  []
# 2   [Buenos días recomendamos lavar a mano con det...
# 3   [Buenas tardes en tallaje nacional normalmente...
# 4   [Buenas tardes para persona que calce 37 la pa...
# 5   [Al momento de la compra, eliges la talla que ...
# 6   [¡Hola! Actualmente, no tenemos disponible la ...
# 7   [Hola, el tiempo de entrega estimado es de 3 a...
# 8   [Beun dia, no es probable, te llegan el sabado...
# 9   [No manejamos esa talla, Hola! Puedes verifica...
# 10  [Hola buen día, no no tenemos disponibles, Hol...
# 11  [¡Hola! La suela de las pantuflas FC Barcelona...
# 12                                                 []
# 13  [Entiendo tu preocupación con respecto al enví...
# 14                                                 []
# 15  [Buenos días. Si en la página le aparece “lleg...
# 16  [Hola buenas noches, si, Hola como estás, vien...
# 17                                                 []
# 18                                                 []
# 19                                                 []

# %%
# Guardar el DataFrame en un archivo de excel
# Se decambiar ruta y nombre del archivo.
#df.to_excel('../Datos/productos_urls_test_ext_scraped_25feb.xlsx', index=False)
#print("Archivo guardado exitosamente.")

# %% [markdown]
# ## Fase 4 Exploracion de los datos recolectados.

# %%
import ast

# Convertir los valores de 'comentarios', 'preguntas' y 'respuestas' en listas reales si están en formato de string
def safe_eval(x):
    if isinstance(x, str):
        try:
            return ast.literal_eval(x)
        except:
            return []
    return x if isinstance(x, list) else []

df['comentarios'] = df['comentarios'].apply(safe_eval)
df['preguntas'] = df['preguntas'].apply(safe_eval)
df['respuestas'] = df['respuestas'].apply(safe_eval)

# Contar la cantidad de elementos en cada lista, asegurándonos de que sean listas antes de aplicar len()
df['cantidad_comentarios'] = df['comentarios'].apply(lambda x: len(x) if isinstance(x, list) else 0)
df['cantidad_preguntas'] = df['preguntas'].apply(lambda x: len(x) if isinstance(x, list) else 0)
df['cantidad_respuestas'] = df['respuestas'].apply(lambda x: len(x) if isinstance(x, list) else 0)

df.head()
# Out:
#                                          descripcion  \
# 0  Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 1  Pantuflas Mujer Hombre Niño Weps Termicas Anti...
# 2  Babuchas Y Pantuflas Hermosas Para Toda La Fam...
# 3  Pantufla Babucha Térmica Para Caballero Algodó...
# 4  Babuchas Pantuflas Termica, Antideslizante Unisex
#
#                                         url_producto    id_producto  \
# 0  https://click1.mercadolibre.com.co/mclics/clic...           None
# 1  https://click1.mercadolibre.com.co/mclics/clic...           None
# 2  https://articulo.mercadolibre.com.co/MCO-58236...   MCO582360754
# 3  https://articulo.mercadolibre.com.co/MCO-60118...   MCO601180326
# 4  https://articulo.mercadolibre.com.co/MCO-19204...  MCO1920460324
#
#                                        url_preguntas  \
# 0                                               None
# 1                                               None
# 2  https://articulo.mercadolibre.com.co/noindex/q...
# 3  https://articulo.mercadolibre.com.co/noindex/q...
# 4  https://articulo.mercadolibre.com.co/noindex/q...
#
#                                          descripcion  precio  \
# 0  Babuchas Y Pantuflas Hermosas Para Toda La Fam...  42.000
# 1  Pantuflas Mujer Hombre Niño Weps Termicas Anti...  59.990
# 2  Babuchas Y Pantuflas Hermosas Para Toda La Fam...  42.000
# 3  Pantufla Babucha Térmica Para Caballero Algodó...  47.500
# 4  Babuchas Pantuflas Termica, Antideslizante Unisex  55.000
#
#                    calificacion_completa      calificaciones valoracion  \
# 0  Calificación 4.8 de 5. 282 opiniones.  282 calificaciones        4.8
# 1   Calificación 4.4 de 5. 26 opiniones.   26 calificaciones        4.4
# 2  Calificación 4.8 de 5. 282 opiniones.  282 calificaciones        4.8
# 3  Calificación 4.7 de 5. 200 opiniones.  200 calificaciones        4.7
# 4   Calificación 4.5 de 5. 78 opiniones.   78 calificaciones        4.5
#
#   calificacion_superior calificaciones_superior        vendor_superior  \
# 0                   4.8                   (282)               ROCHY 27
# 1                   4.4                    (26)             BUILDER CO
# 2                   4.8                   (282)               ROCHY 27
# 3                   4.7                   (200)        AMARE_PANTUFLAS
# 4                   4.5                    (78)  MULTIPLACECOLOMBIACOM
#
#                vendor_inferior comentario_cantidad  \
# 0         Vendido por ROCHY 27               (282)
# 1                No disponible                (26)
# 2         Vendido por ROCHY 27               (282)
# 3  Vendido por AMARE_PANTUFLAS               (200)
# 4                No disponible                (78)
#
#                                          comentarios  \
# 0  [100% recomendadas. Excelentes para descansar ...
# 1  [Respondió a mis expectativas., Preciosas exce...
# 2  [100% recomendadas. Excelentes para descansar ...
# 3  [Muy bien producto, me ayudó mucho la especifi...
# 4  [Muy buen producto., Me iba quedando un poco p...
#
#                                            preguntas  \
# 0                                                 []
# 1                                                 []
# 2  [Buenos días, ¿se pueden lavar en lavadora?, Y...
# 3  [Buenas tardes Requiero de su asesoría es para...
# 4  [hola, te quedan color gris, talla 37? no me d...
#
#                                           respuestas  cantidad_comentarios  \
# 0                                                 []                     5
# 1                                                 []                     5
# 2  [Buenos días recomendamos lavar a mano con det...                     5
# 3  [Buenas tardes en tallaje nacional normalmente...                     5
# 4  [Buenas tardes para persona que calce 37 la pa...                     5
#
#    cantidad_preguntas  cantidad_respuestas
# 0                   0                    0
# 1                   0                    0
# 2                  18                   18
# 3                   1                    1
# 4                   4                    4

# %%
# Verificar el resultado
df[['comentarios', 'cantidad_comentarios','cantidad_preguntas','cantidad_respuestas']].head(50)
# Out:
#                                           comentarios  cantidad_comentarios  \
# 0   [100% recomendadas. Excelentes para descansar ...                     5
# 1   [Respondió a mis expectativas., Preciosas exce...                     5
# 2   [100% recomendadas. Excelentes para descansar ...                     5
# 3   [Muy bien producto, me ayudó mucho la especifi...                     5
# 4   [Muy buen producto., Me iba quedando un poco p...                     5
# 5   [Muy cómodas me gustaron muchob., Hermosas y c...                     5
# 6   [Respondió a mis expectativas., Preciosas exce...                     5
# 7   [Muy linda y bellas mis babuchas de gatito!., ...                     5
# 8   [Entre gustos y colores me facinaron calentito...                     5
# 9   [Son realmente muy cómodas. Los materiales qui...                     5
# 10  [, Super bonito., , Justo lo que esperaba., Di...                     5
# 11  [Eran para un regalo.\nMuy cómodas.\nAl estamp...                     4
# 12  [Lindas pero no tan bien cocidas., , Excelente...                     3
# 13  [Es bueno, pero debe informarse mejor sobre el...                     4
# 14  [Excelente, muy suaves y cómodas., Muy bueno. ...                     5
# 15  [Me encabto., Son hermosaa y suaves!., Hermosa...                     5
# 16  [Buen producto., Muy lindas, de buena calidad ...                     5
# 17  [Son justo lo que esperaba, a mi novia le enca...                     3
# 18  [Me encantaron. Son cómodas y se ven muy hermo...                     5
# 19  [Gracias, a mi amiga lesbi le encantaron 200 d...                     3
# 20  [Hermosas., Son muy cómodas y me encanta el mo...                     5
# 21  [Excelente !., Son hermosas., Muy buen product...                     5
# 22  [Por el valor, cumple las expectativas. No me ...                     5
# 23  [Muy buenas recomendada, antes de comprar medi...                     5
# 24                                    [No disponible]                     1
# 25  [Están lindas, muy buenos materiales! aunque p...                     5
# 26  [Muy bonitas y de excelente calidad, ademas de...                     5
# 27  [Cómodos aunque un poco pequeños para la talla...                     5
# 28  [Buen producto. La zuela si es delgada y se si...                     5
# 29  [Son muy cómodas, principalmente al usarlas de...                     5
# 30  [Son muy lindas, cómodas y llegan antes de tie...                     5
# 31  [Están súper !!! 👌., Excelente, comodo, calien...                     5
# 32                                    [No disponible]                     1
# 33  [En relación al precio esta bien. El material ...                     5
# 34  [Excelent relacion costo-beneficio. Mis hijos ...                     5
# 35  [Son super livianas, cómodas y muy suaves. Gra...                     2
# 36  [Muy bueno., Tal como en las fotos, muy cómodo...                     5
# 37  [Les recomiendo pedir dos tallas más para que ...                     5
# 38  [Perfectas como regalo, muy suaves., Cómodas p...                     4
# 39                                    [No disponible]                     1
# 40  [Dulces, cómodas, cálidas. Me encantaron!., Pe...                     4
# 41  [Perfectas para niños de 1 año y medio y de 3 ...                     4
# 42  [Me encantan. Son muy cómodas y de muuuy buena...                     5
# 43                                          [Comodo.]                     1
# 44  [Muy bonitas son como se ven en la foto, lo ún...                     5
# 45  [, , Excelente., Despues de una semana de uso....                     5
# 46  [Muy utiles., Excelentes, muy cómodas., Cómoda...                     3
# 47  [A las niñas les quedo como estaba esperando.,...                     5
# 48                                    [No disponible]                     1
# 49  [Están bonitas las chanclas pero en relación c...                     2
#
#     cantidad_preguntas  cantidad_respuestas
# 0                    0                    0
# 1                    0                    0
# 2                   18                   18
# 3                    1                    1
# 4                    4                    4
# 5                    3                    3
# 6                    6                    6
# 7                    4                    4
# 8                    9                    9
# 9                   11                   11
# 10                  11                   11
# 11                   8                    8
# 12                   0                    0
# 13                   5                    5
# 14                   0                    0
# 15                   1                    1
# 16                  10                   10
# 17                   0                    0
# 18                   0                    0
# 19                   0                    0
# 20                   3                    3
# 21                   0                    0
# 22                   2                    2
# 23                   4                    4
# 24                   0                    0
# 25                   3                    3
# 26                   2                    2
# 27                   3                    3
# 28                   5                    5
# 29                  15                   15
# 30                   1                    1
# 31                   1                    1
# 32                   1                    1
# 33                   2                    2
# 34                   0                    0
# 35                   2                    2
# 36                   1                    1
# 37                   6                    6
# 38                   1                    1
# 39                   0                    0
# 40                   0                    0
# 41                   0                    0
# 42                   0                    0
# 43                   1                    1
# 44                   3                    3
# 45                   3                    3
# 46                   1                    1
# 47                   2                    2
# 48                   1                    1
# 49                   1                    1

# %%
print(df['cantidad_comentarios'].sum())
print(df['cantidad_preguntas'].sum())
print(df['cantidad_respuestas'].sum())
# Out:
# 211
# 155
# 155
